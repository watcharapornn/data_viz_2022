# %% [markdown]
# <a href="https://colab.research.google.com/github/watcharapornn/data_viz_2022/blob/main/Final_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # โจทย์

# %% [markdown]
# Final Exam: งานกลุ่ม Final ที่อาจารย์สุ่มให้
#
#
# ให้นักศึกษาสร้าง Dashboard แสดงรายงานเกี่ยวกับข้อมูลการตรวจโรค(ov) จาก ไฟล์ alldb.csv และ hospital_list.xlsx
#
#
# ( ดาวน์โหลดจาก https://drive.google.com/drive/folders/1D_Z0fjTki6U6ECbgh2V3wBOSdOXS81YT?fbclid=IwAR3KK7jaRTK1DI3hfBq--qsME4ScgtNdrEbo2yvE2rn08tOTfmXED5kAEB8)
#
#
# โดยข้อมูลหลักจะอยู่ใน ตาราง alldb.csv (ข้อมูลที่สมบูรณ์ที่สามารถนำมาใช้งานได้ต้องมีค่าใน column ต่อไปนี้ดังนี้
#
#
# * user เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# * RowKey เป็น String
# * date เป็น YYYY-MM-DD
# * phone เป็น String
# * site เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# * time เป็น hh-mm-ss
# * urine มีค่า String
# * ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)
# * PartitionKey เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น))
#
#
# ไฟล์ alldb.csv และ hospital_list.xlsx สามารถถูกเชื่อมโยงกันโดย site ในไฟล์ alldb.csv คือ hcode ในไฟล์ hospital_list.xlsx
#
#
# โดยข้อมูลสำคัญที่ต้องแสดงคือ
#
#
# * จำนวนการตรวจในแต่ละพื้นที่ (จังหวัด-อำเภอ ในไฟล์ hospital_list.xlsx) เทียบกับ จำนวนที่พบโรค (column ov ในไฟล์ alldb.csv)
# * ช่วงเวลาที่ตรวจ (date ในไฟล์ alldb.csv)
# * อื่นๆที่นักศึกษาเห็นว่าเป็นประโยชน์ (phone (ชนิดโทรศัพท์ที่ใช้บันทึก), title (คำนำหน้าชื่อ), age (อายุ))
#
#
# (คิดคะแนนตามกลุ่ม final โดยไฟล์ที่ทุกคนในกลุ่มต้องมีคือไฟล์ data pre-processing และ link ไปที่ Dashboard ที่สร้่างโดยเปิดให้สามารถเข้าไปดูและใช้งานได้)
#
#
# ส่งไม่เกิน 23.59 วันจันทร์ที่ 11 เมษายน 2565

# %% [markdown]
# # รายชื่อสมาชิกภายในกลุ่ม triturate

# %% [markdown]
# 1. นางสาววัชราภรณ์ บุญจวง 613020615-8
#
# 2. นางสาวฐิติชญา ไกรวงค์ 623020520-0
#
# 3. นางสาวสุพิชญา ตั้งกิจวานิชย์ 623020542-0
#
# 4. นายดิษพงษ์ นาทองห่อ 623020999-5

# %% [markdown]
# # การเชื่อมไดร์ฟเพื่อดึงข้อมูลจากไดรฟ์

# %%
import pandas as pd #เพื่อใช้ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os           #เพื่อจัดการกับไฟล์ และ ตัว path ที่เราจะนำเข้า

# %%
from google.colab import drive#เชื่อมข้อมูล เพราะเราจะทำการนำเข้าข้อมูล โดยให้ดึงมาจาก google drive ของเรา
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/ovrdt data'
#โดยเราจะทำการระบุให้ชี้ไปที่ โฟลเดอร์ที่เราเซฟไฟล์ไว้ หรือก็คือ โฟลเดอร์ Project

# %%
import pandas as pd
import os
from datetime import datetime as dt
from datetime import time
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# %% [markdown]
# ## ข้อมูลหลัก ตาราง alldb.csv

# %%
alldb = os.path.join(path,'54.xlsx')   
alldb= pd.read_excel(alldb)
alldb
# Out:
#        Column1           user                                    RowKey care  \
# 0            0           test                                       NaN  NaN
# 1            1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 2            2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png  NaN
# 3            3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  NaN
# 4            4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  NaN
# ...        ...            ...                                       ...  ...
# 40030    40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C  NaN
# 40031    40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1  NaN
# 40032    40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9  NaN
# 40033    40033            NaN                            bbuogxulur.png  NaN
# 40034    40034            NaN                            zttpqogiso.png  NaN
#
#             date   ov             phone   site      time            urine  \
# 0            NaT  NaN               NaN    NaN       NaN              NaN
# 1     2022-02-24  NaN        iPhone10,4  05310  10:50:32              NaN
# 2            NaT  NaN               NaN    NaN       NaN              NaN
# 3     2022-02-23  0.0        iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)
# 4     2022-02-23  NaN        iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)
# ...          ...  ...               ...    ...       ...              ...
# 40030        NaT  NaN        iPhone13,4  01234       NaN              NaN
# 40031        NaT  2.0        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)
# 40032        NaT  1.0        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)
# 40033        NaT  NaN  Samsung SM-A115F  01234       NaN              NaN
# 40034        NaT  1.0  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)
#
#        pid            PartitionKey                  title  \
# 0      NaN                     NaN  data is not completed
# 1      NaN                     NaN  data is not completed
# 2      NaN                     NaN  data is not completed
# 3      NaN                     NaN  data is not completed
# 4      NaN                     NaN  data is not completed
# ...    ...                     ...                    ...
# 40030  5.0     เกษศิรินทร์  ไชยลาภ  data is not completed
# 40031  5.0  เถลิงเกียรติ เสริฐเลิศ  data is not completed
# 40032  1.0                    เสรี  data is not completed
# 40033  1.0                    เสรี  data is not completed
# 40034  1.0                    เสรี  data is not completed
#
#                          age
# 0      data is not completed
# 1      data is not completed
# 2      data is not completed
# 3      data is not completed
# 4      data is not completed
# ...                      ...
# 40030  data is not completed
# 40031  data is not completed
# 40032  data is not completed
# 40033  data is not completed
# 40034  data is not completed
#
# [40035 rows x 14 columns]

# %% [markdown]
# ## ข้อมูลรอง ตาราง hospital_list.xlsx

# %%
hospital_list = os.path.join(path,'hospital_list.xlsx')
hospital_list = pd.read_excel(hospital_list)
hospital_list
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ## จัดการข้อมูลหลัก ตาราง alldb.csv

# %% [markdown]
# ### เลือกข้อมูลจากตารางหลัก แค่คอลัมน์ที่ต้องการใช้งาน

# %%
alldb_new = alldb[['user','RowKey','date','phone','site','time','urine','ov','PartitionKey','title','age']] 
alldb_new
# Out:
#                 user                                    RowKey       date  \
# 0               test                                       NaN        NaT
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085 2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png        NaT
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE 2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21 2022-02-23
# ...              ...                                       ...        ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C        NaT
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1        NaT
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9        NaT
# 40033            NaN                            bbuogxulur.png        NaT
# 40034            NaN                            zttpqogiso.png        NaT
#
#                   phone   site      time            urine   ov  \
# 0                   NaN    NaN       NaN              NaN  NaN
# 1            iPhone10,4  05310  10:50:32              NaN  NaN
# 2                   NaN    NaN       NaN              NaN  NaN
# 3            iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)  0.0
# 4            iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)  NaN
# ...                 ...    ...       ...              ...  ...
# 40030        iPhone13,4  01234       NaN              NaN  NaN
# 40031        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)  2.0
# 40032        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)  1.0
# 40033  Samsung SM-A115F  01234       NaN              NaN  NaN
# 40034  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)  1.0
#
#                  PartitionKey                  title                    age
# 0                         NaN  data is not completed  data is not completed
# 1                         NaN  data is not completed  data is not completed
# 2                         NaN  data is not completed  data is not completed
# 3                         NaN  data is not completed  data is not completed
# 4                         NaN  data is not completed  data is not completed
# ...                       ...                    ...                    ...
# 40030     เกษศิรินทร์  ไชยลาภ  data is not completed  data is not completed
# 40031  เถลิงเกียรติ เสริฐเลิศ  data is not completed  data is not completed
# 40032                    เสรี  data is not completed  data is not completed
# 40033                    เสรี  data is not completed  data is not completed
# 40034                    เสรี  data is not completed  data is not completed
#
# [40035 rows x 11 columns]

# %% [markdown]
# ### ตรวจสอบค่า Missing

# %%
alldb_new.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# user            True
# RowKey          True
# date            True
# phone           True
# site            True
# time            True
# urine           True
# ov              True
# PartitionKey    True
# title           True
# age             True
# dtype: bool

# %% [markdown]
# ### ใช้ .dropna ซึ่งจะใช้ตัดแถวข้อมูลที่มีค่า missing

# %%
alldb_drop = alldb_new.dropna() #ใช้ dropna เพื่อต้องการลบข้อมูลทั้งแถวออกเมื่อมีคอลัมน์ใดคอลัมน์หนึ่งเป็น NaN
alldb_drop
# Out:
#          user                                RowKey       date  \
# 186    45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6 2022-02-23
# 187    45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8 2022-02-23
# 188     27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191     12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192     91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# ...       ...                                   ...        ...
# 40013   ttest                        crqcufokmn.png 2022-02-21
# 40014   ttest                        gzxgflnowr.png 2022-02-21
# 40016     xxx                        jytlopevha.png 2022-02-17
# 40022     yyy                        ivccsksowb.png 2022-02-17
# 40023     zzz                        psudrnccsh.png 2022-02-17
#
#                   phone   site      time            urine   ov PartitionKey  \
# 186          iPhone11,8  04312  09:45:28  ปกติ (เหลืองใส)  0.0       0-1528
# 187          iPhone11,8  04312  10:06:45  ปกติ (เหลืองใส)  0.0       0-1544
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 40013  Samsung SM-G998B   test  14:23:45             ขุ่น  2.0         x001
# 40014  Samsung SM-G998B   test  14:23:43             ขุ่น  2.0         x001
# 40016  Samsung SM-N950F    xxx  00:01:06  ปกติ (เหลืองใส)  3.0          xxx
# 40022  Samsung SM-N950F    yyy  08:41:05   มีเม็ดเลือดแดง  2.0          yyy
# 40023  Samsung SM-N950F    zzz  08:41:04          มีตะกอน  2.0          zzz
#
#                        title                    age
# 186    data is not completed  data is not completed
# 187    data is not completed  data is not completed
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# ...                      ...                    ...
# 40013  data is not completed  data is not completed
# 40014  data is not completed  data is not completed
# 40016  data is not completed  data is not completed
# 40022  data is not completed  data is not completed
# 40023  data is not completed  data is not completed
#
# [38134 rows x 11 columns]

# %%
alldb_drop.shape #ตรวจสอบขนาดของตารางใหม่
# Out:
# (38134, 11)

# %%
removes = alldb_new.shape[0] - alldb_drop.shape[0]
print(f'size before drop = {alldb_new.shape[0]}')
print(f'size after drop = {alldb_drop.shape[0]}')
print(f'% from drop = {(removes/alldb_new.shape[0])*100}')
 # จากการคำนวณพบว่ามีข้อมูลที่หายไปเพียงแค่ 3% ดังนั้น จึงสามารถใช้การ .dropna() ได ้
# Out:
# size before drop = 40035
# size after drop = 38134
# % from drop = 4.748345197951792

# %%
alldb_drop.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# user            False
# RowKey          False
# date            False
# phone           False
# site            False
# time            False
# urine           False
# ov              False
# PartitionKey    False
# title           False
# age             False
# dtype: bool

# %% [markdown]
# ### ทำการเปลี่ยน type ของข้อมูลให้เป็น type ที่ถูกต้อง

# %%
alldb_drop.dtypes # เช็คว่าข้อมูลมี่ความตรงกับที่ต้องการหรือไม่
# Out:
# user                    object
# RowKey                  object
# date            datetime64[ns]
# phone                   object
# site                    object
# time                    object
# urine                   object
# ov                     float64
# PartitionKey            object
# title                   object
# age                     object
# dtype: object

# %% [markdown]
# พบว่ามีข้อมูลที่ไม่ตรงกับสิ่งที่ต้องการ
#
#  * user ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int
#  * site ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int
#  * ov ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int
#  * PartitionKey ปัจจุบันยังเป็นข้อมูล type string ควรเปลี่ยนเป็น int

# %% [markdown]
# #### คอลัมน์ user

# %%
set(alldb_drop['user']) # เพื่อดูข้อมูลทั้งหมดใน column user
# Out:
# {'00279',
#  '59144',
#  '19855',
#  '30059',
#  '85989',
#  '16848',
#  '00124',
#  '39537',
#  '30016',
#  '83777',
#  '10724',
#  '43068',
#  '39726',
#  '18849',
#  '77645',
#  '50349',
#  '12413',
#  '05358',
#  '56004',
#  '84187',
#  '25199',
#  '68006',
#  '3451400598487',
#  '03087',
#  'ccc',
#  '31196',
#  '00129',
#  '80374',
#  '45729',
#  '36358',
#  'aiov0001',
#  '23738',
#  '92241',
#  '37551',
#  '80382',
#  '55239',
#  '44888',
#  '00286',
#  '52520',
#  '49308',
#  '05113',
#  '05590',
#  '25403',
#  '02639',
#  '55873',
#  '72483',
#  '33103',
#  '63068',
#  '30511',
#  '31114',
#  '15731',
#  '80880',
#  '57398',
#  '04991',
#  '23012',
#  '29476',
#  '05182',
#  '49596',
#  '00135',
#  '38727',
#  '94406',
#  '77665',
#  '31401',
#  '32831',
#  '05219',
#  '76299',
#  '12044',
#  '01942',
#  '21860',
#  '11742',
#  '00307',
#  '08818',
#  '99734',
#  '12576',
#  '13978',
#  '00291',
#  '63284',
#  '00036',
#  '11027',
#  '00289',
#  '75347',
#  '42468',
#  '54974',
#  '11007',
#  '50624',
#  '17055',
#  '83900',
#  '74335',
#  '70409',
#  '00271',
#  '19699',
#  '37914',
#  '04387',
#  '50373',
#  '00007',
#  '31755',
#  '32914',
#  '26773',
#  '01431',
#  '91402',
#  '98080',
#  '00345',
#  '98156',
#  '14764',
#  '11282',
#  '95301',
#  '41340',
#  '55415',
#  '73946',
#  '00204',
#  '51310',
#  '48514',
#  '53751',
#  '36692',
#  '47567',
#  '05291',
#  '3450100836420',
#  '96061',
#  '23554',
#  '05211',
#  '00183',
#  '05374',
#  '19211',
#  '22804',
#  '43143',
#  '65995',
#  'eee',
#  '00162',
#  '16085',
#  '3450101325119',
#  '45881',
#  '00071',
#  '18890',
#  '00148',
#  '77743',
#  'ppp',
#  'tt',
#  '27143',
#  ...}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข 5 หลัก เท่ากับ ข้อมูลว่าง

# %%
alldb_drop['user'].replace({'3450101325119':None,
'34501009308':None,
'71378\n71378':'71378',
'yyy':None,
'7197':None,
'rrr':None,
'745-61':'74561',
'uuu':None,
'3450100810285':None,
'jjj':None,
'11111111':None,
'3450100805222':None,
'zzz':None,
'3450101556129':None,
'3450101325593':None,
'4':None,
'6724100235':None,
'17536\n\n17536':'17536',
'3450101229373':None,
'Testtohn':None,
'  noknoi2601@gmail.com\n':None,
'3451100324624':None,
'40591\n40591\n':'40591',
'6724-':None,
'test':None,
'3450101536268':None,
'3450100543961':None,
'ppp':None,
'xxx':None,
'3451100451758':None,
'hhh':None,
'ttohn':None,
'fff':None,
'ggg':None,
'ccc':None,
'5600190011969':None,
'testtohn':None,
'3451400598487':None,
'3':None,
'3400900747146':None,
'5450100026807':None,
'iii':None,
'5799':None,
'aaa':None,
'3451100141252':None,
't006':None,
'5450500072920':None,
'bbb':None,
'hu':None,
'3450101323370':None,
'ttest':None,
'test1':None,
'tttt':None,
'eee':None,
'qqq':None,
'ttt':None,
'45-161':None,
'sss':None,
'tt':None,
'u789':None,
'3451100241281':None,
'3451100324713':None,
'3450101514299':None,
'3451100451251':None,
'1450700099250':None,
'3450100836420':None,
'3450500541443':None,
'www':None,
'5451100055352':None,
'3451100146637':None,
'3450100940367':None,
'mmm':None,
'3460500500020':None,
'vvv':None,
'lll':None,
'3450101325097':None,
'aiov0001':None,
'kkk':None,
'mks':None,
'aiov0002':None,
'3459900286317':None,
'3451100150251':None,
'3450101576642':None,
'  67241\n':'67241'
},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
#  '03087',
#  '31196',
#  '00129',
#  '80374',
#  '45729',
#  '36358',
#  '23738',
#  '92241',
#  '37551',
#  '80382',
#  '55239',
#  '44888',
#  '00286',
#  '52520',
#  '49308',
#  '05113',
#  '05590',
#  '25403',
#  '02639',
#  '55873',
#  '72483',
#  '33103',
#  '63068',
#  '30511',
#  '31114',
#  '15731',
#  '80880',
#  '57398',
#  '04991',
#  '23012',
#  '29476',
#  '05182',
#  '49596',
#  '00135',
#  '38727',
#  '94406',
#  '77665',
#  '31401',
#  '32831',
#  '05219',
#  '76299',
#  '12044',
#  '01942',
#  '21860',
#  '11742',
#  '00307',
#  '08818',
#  '99734',
#  '12576',
#  '13978',
#  '00291',
#  '63284',
#  '00036',
#  '11027',
#  '00289',
#  '75347',
#  '42468',
#  '54974',
#  '11007',
#  '50624',
#  '17055',
#  '83900',
#  '74335',
#  '70409',
#  '00271',
#  '19699',
#  '37914',
#  '04387',
#  '50373',
#  '00007',
#  '31755',
#  '32914',
#  '26773',
#  '01431',
#  '91402',
#  '98080',
#  '00345',
#  '98156',
#  '14764',
#  '11282',
#  '95301',
#  '41340',
#  '55415',
#  '73946',
#  '00204',
#  '51310',
#  '48514',
#  '53751',
#  '36692',
#  '47567',
#  '05291',
#  '96061',
#  '23554',
#  '05211',
#  '00183',
#  '05374',
#  '19211',
#  '22804',
#  '43143',
#  '65995',
#  '00162',
#  '16085',
#  '45881',
#  '00071',
#  '18890',
#  '00148',
#  '77743',
#  '27143',
#  '48710',
#  '03949',
#  '00394',
#  '68037',
#  '50047',
#  '72169',
#  '27902',
#  '76459',
#  '67241',
#  '50332',
#  '02759',
#  '85379',
#  '32796',
#  '11165',
#  '47122',
#  '39079',
#  '84005',
#  '45485',
#  '00121',
#  '00161',
#  '46566',
#  '56845',
#  '68162',
#  '42453',
#  '66261',
#  '48393',
#  '31577',
#  '97913',
#  '44018',
#  '19559',
#  '00304',
#  '08602',
#  '16725',
#  '61746',
#  '93991',
#  '55365',
#  '28992',
#  '11611',
#  '52209',
#  '02128',
#  '63274',
#  '00277',
#  ...}

# %%
alldb_drop2 = alldb_drop.dropna() # ทำการ drop ค่าว่างออก 
alldb_drop2 # แสดงผลลัพธ์
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39722  76331                        bbrbiwclgv.png 2022-02-23
# 39782  76331                        lzzsckyyqs.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine   ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3.0        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 39722  Samsung SM-G965U  05258  14:05:25  ปกติ (เหลืองใส)  0.0           61
# 39782  Samsung SM-G965U  05258  14:42:45  ปกติ (เหลืองใส)  0.0           89
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1.0           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2.0          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2.0          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39722  data is not completed  data is not completed
# 39782  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37481 rows x 11 columns]

# %%
alldb_drop2 = alldb_drop2[(alldb_drop2['user'].astype(str).str.isdigit()) & (alldb_drop2['user'].str.len() == 5 )] # เลือกข้อมูลที่เป็น 5 หลัก

# %%
alldb_drop2
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39722  76331                        bbrbiwclgv.png 2022-02-23
# 39782  76331                        lzzsckyyqs.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine   ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3.0        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 39722  Samsung SM-G965U  05258  14:05:25  ปกติ (เหลืองใส)  0.0           61
# 39782  Samsung SM-G965U  05258  14:42:45  ปกติ (เหลืองใส)  0.0           89
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1.0           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2.0          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2.0          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39722  data is not completed  data is not completed
# 39782  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37473 rows x 11 columns]

# %% [markdown]
# #### คอลัมน์ site

# %%
set(alldb_drop2['site']) # เพื่อดูข้อมูลทั้งหมดใน column site
# Out:
# {'00027',
#  '00040',
#  '00513',
#  '00579',
#  '00580',
#  '01151',
#  '02759',
#  '03432',
#  '03626',
#  '04275',
#  '04279',
#  '04280',
#  '04281',
#  '04302',
#  '04312',
#  '04313',
#  '04321',
#  '04322',
#  '04326',
#  '04337',
#  '04347',
#  '04349',
#  '04351',
#  '04352',
#  '04355',
#  '04374',
#  '04376',
#  '04380',
#  '04384',
#  '04387',
#  '04388',
#  '04390',
#  '04391',
#  '04396',
#  '04399',
#  '04401',
#  '04402',
#  '04403',
#  '04404',
#  '04405',
#  '04406',
#  '04407',
#  '04408',
#  '04433',
#  '04434',
#  '04435',
#  '04436',
#  '04437',
#  '04438',
#  '04441',
#  '04443',
#  '04455',
#  '04456',
#  '04457',
#  '04458',
#  '04475',
#  '04478',
#  '04558',
#  '04936',
#  '04968',
#  '04970',
#  '04971',
#  '04973',
#  '04974',
#  '04977',
#  '04980',
#  '04981',
#  '04982',
#  '04983',
#  '04984',
#  '04985',
#  '04986',
#  '04989',
#  '04990',
#  '04992',
#  '04993',
#  '04994',
#  '04995',
#  '04996',
#  '04997',
#  '04999',
#  '05000',
#  '05001',
#  '05002',
#  '05003',
#  '05004',
#  '05005',
#  '05006',
#  '05007',
#  '05008',
#  '05009',
#  '05010',
#  '05011',
#  '05012',
#  '05013',
#  '05015',
#  '05016',
#  '05019',
#  '05021',
#  '05022',
#  '05023',
#  '05024',
#  '05025',
#  '05026',
#  '05027',
#  '05028',
#  '05029',
#  '05032',
#  '05033',
#  '05034',
#  '05035',
#  '05038',
#  '05040',
#  '05042',
#  '05044',
#  '05045',
#  '05047',
#  '05048',
#  '05049',
#  '05052',
#  '05054',
#  '05055',
#  '05058',
#  '05059',
#  '05060',
#  '05061',
#  '05062',
#  '05063',
#  '05064',
#  '05065',
#  '05066',
#  '05067',
#  '05068',
#  '05069',
#  '05072',
#  '05074',
#  '05075',
#  '05077',
#  '05080',
#  '05081',
#  '05082',
#  '05083',
#  '05084',
#  '05086',
#  '05087',
#  '05088',
#  '05090',
#  '05091',
#  '05094',
#  '05097',
#  '05098',
#  '05100',
#  '05101',
#  '05102',
#  '05103',
#  '05107',
#  '05111',
#  '05112',
#  '05113',
#  '05115',
#  '05116',
#  '05117',
#  '05119',
#  '05120',
#  '05123',
#  '05125',
#  '05126',
#  '05128',
#  '05129',
#  '05131',
#  '05132',
#  '05133',
#  '05135',
#  '05136',
#  '05141',
#  '05143',
#  '05144',
#  '05146',
#  '05147',
#  '05152',
#  '05154',
#  '05157',
#  '05158',
#  '05162',
#  '05166',
#  '05172',
#  '05173',
#  '05175',
#  '05177',
#  '05178',
#  '05180',
#  '05181',
#  '05182',
#  '05185',
#  '05187',
#  '05188',
#  '05192',
#  '05193',
#  '05194',
#  '05195',
#  '05196',
#  '05198',
#  '05200',
#  '05203',
#  '05205',
#  '05207',
#  '05210',
#  '05211',
#  '05213',
#  '05214',
#  '05215',
#  '05219',
#  '05220',
#  '05222',
#  '05223',
#  '05224',
#  '05225',
#  '05226',
#  '05228',
#  '05229',
#  '05233',
#  '05236',
#  '05237',
#  '05238',
#  '05240',
#  '05242',
#  '05244',
#  '05245',
#  '05246',
#  '05247',
#  '05248',
#  '05249',
#  '05250',
#  '05250\n',
#  '05251',
#  '05252',
#  '05253',
#  '05254',
#  '05256',
#  '05257',
#  '05258',
#  '05259',
#  '05260',
#  '05261',
#  '05264',
#  '05265',
#  '05291',
#  '05298',
#  '05300',
#  '05304',
#  '05310',
#  '05311',
#  '05312',
#  '05313',
#  '05314',
#  '05315',
#  '05316',
#  '05322',
#  '05323',
#  '05324',
#  '05325',
#  '05327',
#  '05328',
#  '05332',
#  '05335',
#  '05337',
#  '05338',
#  '05339',
#  '05340',
#  '05343',
#  '05344',
#  '05345',
#  '05346',
#  '05349',
#  '05350',
#  '05350ยอ',
#  '05351',
#  '05352',
#  '05354',
#  '05355',
#  '05356',
#  '05357',
#  '05358',
#  '05359',
#  '05360',
#  '05361',
#  '05363',
#  '05365',
#  '05366',
#  '05367',
#  '05368',
#  '05370',
#  '05371',
#  '05373',
#  '05378',
#  '05386',
#  '05391',
#  '05392',
#  '05393',
#  '05394',
#  '05395',
#  '05396',
#  '05413',
#  '05414',
#  '05415',
#  '05416',
#  '05418',
#  '05419',
#  '05422',
#  '05423',
#  '05424',
#  '05425',
#  '05428',
#  '05431',
#  '05432',
#  '05433',
#  '05434',
#  '05435',
#  '05436',
#  '05437',
#  '05439',
#  '05440',
#  '05441',
#  '05442',
#  '05541',
#  '06238',
#  '06251',
#  '06253',
#  '06254',
#  '06255',
#  '06256',
#  '06257',
#  '06259',
#  '06260',
#  '06261',
#  '06263',
#  '06265',
#  '06267',
#  '06268',
#  '06270',
#  '06271',
#  '06272',
#  '06273',
#  '06274',
#  '06275',
#  '06276',
#  '06277',
#  '06278',
#  '06279',
#  '06280',
#  '06281',
#  '06282',
#  '06283',
#  '06285',
#  '06286',
#  '06287',
#  '06288',
#  '06289',
#  '06290',
#  '06291',
#  '06292',
#  '06293',
#  '06294',
#  '06295',
#  '06296',
#  '06297',
#  '06298',
#  '06299',
#  '06300',
#  '06301',
#  '06302',
#  '06307',
#  '06308',
#  '06309',
#  '06310',
#  '06311',
#  '06312',
#  '06314',
#  '06315',
#  '06316',
#  '06318',
#  '06319',
#  '06320',
#  '06321',
#  '06322',
#  '06323',
#  '06324',
#  '06325',
#  '06326',
#  '06327',
#  '06328',
#  '06329',
#  '06330',
#  '06331',
#  '06332',
#  '06333',
#  '06334',
#  '10360',
#  '10673',
#  '11010',
#  '11055',
#  '11056',
#  '11057',
#  '11059',
#  '11060',
#  '11066',
#  '11069',
#  '11070',
#  '11072',
#  '11073',
#  '11084',
#  '11088',
#  '11158',
#  '11159',
#  '11160',
#  '11161',
#  '11163',
#  '11164',
#  '11165',
#  '11748',
#  '11749',
#  '13777',
#  '13937',
#  '13941',
#  '13943',
#  '13943\n\n',
#  '13944',
#  '13946',
#  '13947',
#  '13948',
#  '13949',
#  '13952',
#  '13953',
#  '13954',
#  '13955',
#  '13962',
#  '13963',
#  '13966',
#  '13984',
#  '14005',
#  '14007',
#  '14280',
#  '14284',
#  '14843',
#  '24650',
#  '27988',
#  '27990',
#  '28017',
#  '99795'}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข 5 หลัก เท่ากับ ข้อมูลว่าง

# %%
alldb_drop2['site'].replace({' 0502':None,
'05250\n':'05250',
'05350ยอ':'05350',
'13943\n\n':'13943',
'043.1':None
},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
alldb_drop3 = alldb_drop2.dropna() # ทำการ drop ค่าว่างออก 
alldb_drop3 # แสดงผลลัพธ์
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39722  76331                        bbrbiwclgv.png 2022-02-23
# 39782  76331                        lzzsckyyqs.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine   ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3.0        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 39722  Samsung SM-G965U  05258  14:05:25  ปกติ (เหลืองใส)  0.0           61
# 39782  Samsung SM-G965U  05258  14:42:45  ปกติ (เหลืองใส)  0.0           89
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1.0           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2.0          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2.0          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39722  data is not completed  data is not completed
# 39782  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37473 rows x 11 columns]

# %%
set(alldb_drop3['site']) # เพื่อดูข้อมูลทั้งหมดใน column site
# Out:
# {'00027',
#  '00040',
#  '00513',
#  '00579',
#  '00580',
#  '01151',
#  '02759',
#  '03432',
#  '03626',
#  '04275',
#  '04279',
#  '04280',
#  '04281',
#  '04302',
#  '04312',
#  '04313',
#  '04321',
#  '04322',
#  '04326',
#  '04337',
#  '04347',
#  '04349',
#  '04351',
#  '04352',
#  '04355',
#  '04374',
#  '04376',
#  '04380',
#  '04384',
#  '04387',
#  '04388',
#  '04390',
#  '04391',
#  '04396',
#  '04399',
#  '04401',
#  '04402',
#  '04403',
#  '04404',
#  '04405',
#  '04406',
#  '04407',
#  '04408',
#  '04433',
#  '04434',
#  '04435',
#  '04436',
#  '04437',
#  '04438',
#  '04441',
#  '04443',
#  '04455',
#  '04456',
#  '04457',
#  '04458',
#  '04475',
#  '04478',
#  '04558',
#  '04936',
#  '04968',
#  '04970',
#  '04971',
#  '04973',
#  '04974',
#  '04977',
#  '04980',
#  '04981',
#  '04982',
#  '04983',
#  '04984',
#  '04985',
#  '04986',
#  '04989',
#  '04990',
#  '04992',
#  '04993',
#  '04994',
#  '04995',
#  '04996',
#  '04997',
#  '04999',
#  '05000',
#  '05001',
#  '05002',
#  '05003',
#  '05004',
#  '05005',
#  '05006',
#  '05007',
#  '05008',
#  '05009',
#  '05010',
#  '05011',
#  '05012',
#  '05013',
#  '05015',
#  '05016',
#  '05019',
#  '05021',
#  '05022',
#  '05023',
#  '05024',
#  '05025',
#  '05026',
#  '05027',
#  '05028',
#  '05029',
#  '05032',
#  '05033',
#  '05034',
#  '05035',
#  '05038',
#  '05040',
#  '05042',
#  '05044',
#  '05045',
#  '05047',
#  '05048',
#  '05049',
#  '05052',
#  '05054',
#  '05055',
#  '05058',
#  '05059',
#  '05060',
#  '05061',
#  '05062',
#  '05063',
#  '05064',
#  '05065',
#  '05066',
#  '05067',
#  '05068',
#  '05069',
#  '05072',
#  '05074',
#  '05075',
#  '05077',
#  '05080',
#  '05081',
#  '05082',
#  '05083',
#  '05084',
#  '05086',
#  '05087',
#  '05088',
#  '05090',
#  '05091',
#  '05094',
#  '05097',
#  '05098',
#  '05100',
#  '05101',
#  '05102',
#  '05103',
#  '05107',
#  '05111',
#  '05112',
#  '05113',
#  '05115',
#  '05116',
#  '05117',
#  '05119',
#  '05120',
#  '05123',
#  '05125',
#  '05126',
#  '05128',
#  '05129',
#  '05131',
#  '05132',
#  '05133',
#  '05135',
#  '05136',
#  '05141',
#  '05143',
#  '05144',
#  '05146',
#  '05147',
#  '05152',
#  '05154',
#  '05157',
#  '05158',
#  '05162',
#  '05166',
#  '05172',
#  '05173',
#  '05175',
#  '05177',
#  '05178',
#  '05180',
#  '05181',
#  '05182',
#  '05185',
#  '05187',
#  '05188',
#  '05192',
#  '05193',
#  '05194',
#  '05195',
#  '05196',
#  '05198',
#  '05200',
#  '05203',
#  '05205',
#  '05207',
#  '05210',
#  '05211',
#  '05213',
#  '05214',
#  '05215',
#  '05219',
#  '05220',
#  '05222',
#  '05223',
#  '05224',
#  '05225',
#  '05226',
#  '05228',
#  '05229',
#  '05233',
#  '05236',
#  '05237',
#  '05238',
#  '05240',
#  '05242',
#  '05244',
#  '05245',
#  '05246',
#  '05247',
#  '05248',
#  '05249',
#  '05250',
#  '05251',
#  '05252',
#  '05253',
#  '05254',
#  '05256',
#  '05257',
#  '05258',
#  '05259',
#  '05260',
#  '05261',
#  '05264',
#  '05265',
#  '05291',
#  '05298',
#  '05300',
#  '05304',
#  '05310',
#  '05311',
#  '05312',
#  '05313',
#  '05314',
#  '05315',
#  '05316',
#  '05322',
#  '05323',
#  '05324',
#  '05325',
#  '05327',
#  '05328',
#  '05332',
#  '05335',
#  '05337',
#  '05338',
#  '05339',
#  '05340',
#  '05343',
#  '05344',
#  '05345',
#  '05346',
#  '05349',
#  '05350',
#  '05351',
#  '05352',
#  '05354',
#  '05355',
#  '05356',
#  '05357',
#  '05358',
#  '05359',
#  '05360',
#  '05361',
#  '05363',
#  '05365',
#  '05366',
#  '05367',
#  '05368',
#  '05370',
#  '05371',
#  '05373',
#  '05378',
#  '05386',
#  '05391',
#  '05392',
#  '05393',
#  '05394',
#  '05395',
#  '05396',
#  '05413',
#  '05414',
#  '05415',
#  '05416',
#  '05418',
#  '05419',
#  '05422',
#  '05423',
#  '05424',
#  '05425',
#  '05428',
#  '05431',
#  '05432',
#  '05433',
#  '05434',
#  '05435',
#  '05436',
#  '05437',
#  '05439',
#  '05440',
#  '05441',
#  '05442',
#  '05541',
#  '06238',
#  '06251',
#  '06253',
#  '06254',
#  '06255',
#  '06256',
#  '06257',
#  '06259',
#  '06260',
#  '06261',
#  '06263',
#  '06265',
#  '06267',
#  '06268',
#  '06270',
#  '06271',
#  '06272',
#  '06273',
#  '06274',
#  '06275',
#  '06276',
#  '06277',
#  '06278',
#  '06279',
#  '06280',
#  '06281',
#  '06282',
#  '06283',
#  '06285',
#  '06286',
#  '06287',
#  '06288',
#  '06289',
#  '06290',
#  '06291',
#  '06292',
#  '06293',
#  '06294',
#  '06295',
#  '06296',
#  '06297',
#  '06298',
#  '06299',
#  '06300',
#  '06301',
#  '06302',
#  '06307',
#  '06308',
#  '06309',
#  '06310',
#  '06311',
#  '06312',
#  '06314',
#  '06315',
#  '06316',
#  '06318',
#  '06319',
#  '06320',
#  '06321',
#  '06322',
#  '06323',
#  '06324',
#  '06325',
#  '06326',
#  '06327',
#  '06328',
#  '06329',
#  '06330',
#  '06331',
#  '06332',
#  '06333',
#  '06334',
#  '10360',
#  '10673',
#  '11010',
#  '11055',
#  '11056',
#  '11057',
#  '11059',
#  '11060',
#  '11066',
#  '11069',
#  '11070',
#  '11072',
#  '11073',
#  '11084',
#  '11088',
#  '11158',
#  '11159',
#  '11160',
#  '11161',
#  '11163',
#  '11164',
#  '11165',
#  '11748',
#  '11749',
#  '13777',
#  '13937',
#  '13941',
#  '13943',
#  '13944',
#  '13946',
#  '13947',
#  '13948',
#  '13949',
#  '13952',
#  '13953',
#  '13954',
#  '13955',
#  '13962',
#  '13963',
#  '13966',
#  '13984',
#  '14005',
#  '14007',
#  '14280',
#  '14284',
#  '14843',
#  '24650',
#  '27988',
#  '27990',
#  '28017',
#  '99795'}

# %%
alldb_drop3 = alldb_drop3[(alldb_drop3['site'].astype(str).str.isdigit()) & (alldb_drop3['site'].str.len() == 5 )] # เลือกข้อมูลที่เป็น 5 หลัก

# %%
alldb_drop3
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39722  76331                        bbrbiwclgv.png 2022-02-23
# 39782  76331                        lzzsckyyqs.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine   ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3.0        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 39722  Samsung SM-G965U  05258  14:05:25  ปกติ (เหลืองใส)  0.0           61
# 39782  Samsung SM-G965U  05258  14:42:45  ปกติ (เหลืองใส)  0.0           89
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1.0           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2.0          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2.0          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39722  data is not completed  data is not completed
# 39782  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37473 rows x 11 columns]

# %% [markdown]
# #### คอลัมน์ ov

# %%
set(alldb_drop3['ov']) # เพื่อดูข้อมูลทั้งหมดใน column ov
# Out:
# {0.0, 1.0, 2.0, 3.0, 4.0}

# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข  เท่ากับ ข้อมูลว่าง

# %%
alldb_drop3['ov'].replace({'ติดเชื้อ +2 ':None},inplace=True)

# %%
alldb_drop4 = alldb_drop3.dropna() # ทำการ drop ค่าว่างออก 
alldb_drop4 # แสดงผลลัพธ์
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39722  76331                        bbrbiwclgv.png 2022-02-23
# 39782  76331                        lzzsckyyqs.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine   ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0.0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4.0        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4.0        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3.0        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3.0        00001
# ...                 ...    ...       ...              ...  ...          ...
# 39722  Samsung SM-G965U  05258  14:05:25  ปกติ (เหลืองใส)  0.0           61
# 39782  Samsung SM-G965U  05258  14:42:45  ปกติ (เหลืองใส)  0.0           89
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1.0           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2.0          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2.0          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39722  data is not completed  data is not completed
# 39782  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37473 rows x 11 columns]

# %%
set(alldb_drop4['ov']) # เพื่อดูข้อมูลทั้งหมดใน column ov
# Out:
# {0.0, 1.0, 2.0, 3.0, 4.0}

# %%
alldb_drop4['ov'] = alldb_drop4['ov'].astype(int) # เปลี่ยนข้อมูลจาก string เป็น int ในคอลัมน์ ov

# %%
alldb_drop4.dtypes # เช็คว่า ov ทั้งหมดเป็น int หรือไม่
# Out:
# user                    object
# RowKey                  object
# date            datetime64[ns]
# phone                   object
# site                    object
# time                    object
# urine                   object
# ov                       int64
# PartitionKey            object
# title                   object
# age                     object
# dtype: object

# %% [markdown]
# #### คอลัมน์ PartitionKey

# %%
set(alldb_drop4['PartitionKey']) # เพื่อดูข้อมูลทั้งหมดใน column PartitionKey
# Out:
# {'01102',
#  '00279',
#  '01917',
#  '01031',
#  '00558',
#  '02417',
#  '08972',
#  '01195',
#  '03094',
#  '02534',
#  '05318',
#  '00377',
#  '01827',
#  '01631',
#  '00581',
#  '00478',
#  '01120',
#  '00124',
#  '01909',
#  '03511',
#  '00390',
#  '08943',
#  '04670',
#  '01045',
#  '01860',
#  '08956',
#  '01859',
#  '00375',
#  '02098',
#  '01862',
#  '03032',
#  '01681',
#  '05267',
#  '02494',
#  '01249',
#  '01925',
#  '00870',
#  '02523',
#  '00057',
#  '03824',
#  '02823',
#  '01082',
#  '01560',
#  '02122',
#  '01383',
#  '02248',
#  '02563',
#  '03496',
#  '06047',
#  '02761',
#  '04661',
#  '00398',
#  '02312',
#  '01812',
#  '01880',
#  '08977',
#  '01683',
#  '08925',
#  '00010',
#  '05238',
#  '00190',
#  '01808',
#  '00720',
#  '00033',
#  '02480',
#  '01943',
#  '00935',
#  '02398',
#  '03432',
#  '01726',
#  '03239',
#  '03183',
#  '08900',
#  '01022',
#  '02787',
#  '03445',
#  '01607',
#  '01348',
#  '00122',
#  '01421',
#  '00412',
#  '02038',
#  '01813',
#  '00820',
#  '00044',
#  '04136',
#  '00783',
#  '00881',
#  '01731',
#  '01044',
#  '05975',
#  '01020',
#  '00009',
#  '00246',
#  '00026',
#  '03398',
#  '00835',
#  '02080',
#  '01828',
#  '01844',
#  '01594',
#  '00078',
#  '03925',
#  '00166',
#  '00649',
#  '04080',
#  '00949',
#  '00606',
#  '04054',
#  '02271',
#  '02330',
#  '02230',
#  '05721',
#  '03980',
#  '00303',
#  '00314',
#  '01068',
#  '01833',
#  '08913',
#  '01457',
#  '01753',
#  '00116',
#  '04073',
#  '06037',


# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข 5 หลัก เท่ากับ ข้อมูลว่าง

# %%
alldb_drop4['PartitionKey'].replace({
'61':None,
'29':None,
'52':None,
'0083':None,
'000152':None,
'0034':None,
'23':None,
'219':None,
'185':None,
'00\u200b175':None,
'89':None,
'150':None,
'196':None,
'193':None,
'125':None,
'1881':None,
'32':None,
'124':None,
'112':None,
'00083\u200b':None,
'002.5':None                         
},inplace=True)

# %%
alldb_drop5 = alldb_drop4.dropna() # ทำการ drop ค่าว่างออก 
alldb_drop5 # แสดงผลลัพธ์
# Out:
#         user                                RowKey       date  \
# 188    27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 39699  76331                        lbqlcrqxli.png 2022-02-23
# 39710  76331                        qofmbraznv.png 2022-02-23
# 39791  76331                        pvpiawlexb.png 2022-02-23
# 39794  68317                        rtutxrlbam.png 2022-02-23
# 39795  68317                        dmuragqwza.png 2022-02-23
#
#                   phone   site      time            urine  ov PartitionKey  \
# 188          iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)   0         0000
# 191          iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)   4        00001
# 192          iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)   4        00001
# 193          iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)   3        00001
# 194           iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)   3        00001
# ...                 ...    ...       ...              ...  ..          ...
# 39699  Samsung SM-G965U  05258  14:22:42  ปกติ (เหลืองใส)   0           48
# 39710  Samsung SM-G965U  05258  14:08:37  ปกติ (เหลืองใส)   0           56
# 39791  Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)   1           92
# 39794  Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)   2          976
# 39795  Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)   2          983
#
#                        title                    age
# 188    data is not completed  data is not completed
# 191                   นางสาว                     47
# 192                      นาง                     41
# 193                      นาง                     55
# 194                      นาย                     66
# ...                      ...                    ...
# 39699  data is not completed  data is not completed
# 39710  data is not completed  data is not completed
# 39791  data is not completed  data is not completed
# 39794  data is not completed  data is not completed
# 39795  data is not completed  data is not completed
#
# [37452 rows x 11 columns]

# %%
set(alldb_drop5['PartitionKey']) # เพื่อดูข้อมูลทั้งหมดใน column PartitionKey
# Out:
# {'01102',
#  '00279',
#  '01917',
#  '01031',
#  '00558',
#  '02417',
#  '08972',
#  '01195',
#  '03094',
#  '02534',
#  '05318',
#  '00377',
#  '01827',
#  '01631',
#  '00581',
#  '00478',
#  '01120',
#  '00124',
#  '01909',
#  '03511',
#  '00390',
#  '08943',
#  '04670',
#  '01045',
#  '01860',
#  '08956',
#  '01859',
#  '00375',
#  '02098',
#  '01862',
#  '03032',
#  '01681',
#  '05267',
#  '02494',
#  '01249',
#  '01925',
#  '00870',
#  '02523',
#  '00057',
#  '03824',
#  '02823',
#  '01082',
#  '01560',
#  '02122',
#  '01383',
#  '02248',
#  '02563',
#  '03496',
#  '06047',
#  '02761',
#  '04661',
#  '00398',
#  '02312',
#  '01812',
#  '01880',
#  '08977',
#  '01683',
#  '08925',
#  '00010',
#  '05238',
#  '00190',
#  '01808',
#  '00720',
#  '00033',
#  '02480',
#  '01943',
#  '00935',
#  '02398',
#  '03432',
#  '01726',
#  '03239',
#  '03183',
#  '08900',
#  '01022',
#  '02787',
#  '03445',
#  '01607',
#  '01348',
#  '00122',
#  '01421',
#  '00412',
#  '02038',
#  '01813',
#  '00820',
#  '00044',
#  '04136',
#  '00783',
#  '00881',
#  '01731',
#  '01044',
#  '05975',
#  '01020',
#  '00009',
#  '00246',
#  '00026',
#  '03398',
#  '00835',
#  '02080',
#  '01828',
#  '01844',
#  '01594',
#  '00078',
#  '03925',
#  '00166',
#  '00649',
#  '04080',
#  '00949',
#  '00606',
#  '04054',
#  '02271',
#  '02330',
#  '02230',
#  '05721',
#  '03980',
#  '00303',
#  '00314',
#  '01068',
#  '01833',
#  '03221',
#  '00120',
#  '02352',
#  '04630',
#  '06020',
#  '00254',
#  '00169',
#  '03290',
#  '00522',
#  ...}

# %%
alldb_drop5 = alldb_drop5[(alldb_drop5['PartitionKey'].astype(str).str.isdigit()) & (alldb_drop5['PartitionKey'].str.len() == 5 )] # เลือกข้อมูลที่เป็น 5 หลัก

# %%
alldb_drop5
# Out:
#         user                                RowKey       date       phone  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30  iPhone12,3
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30  iPhone14,3
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# ...      ...                                   ...        ...         ...
# 39416  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 39417  26462                        cywpeqziic.png 2022-03-21   Vivo 1920
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22  iPhone13,4
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
# 39420  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site      time                             urine  ov PartitionKey  \
# 191    06307  14:46:08                   ปกติ (เหลืองใส)   4        00001
# 192    05328  15:27:45                   ปกติ (เหลืองใส)   4        00001
# 193    06302  10:16:46                   ปกติ (เหลืองใส)   3        00001
# 194    05059  12:26:38                   ปกติ (เหลืองใส)   3        00001
# 195    06334  14:57:41                   ปกติ (เหลืองใส)   0        00001
# ...      ...       ...                               ...  ..          ...
# 39416  11069  14:03:12                   ปกติ (เหลืองใส)   1        11003
# 39417  11069  13:59:04                   ปกติ (เหลืองใส)   2        11005
# 39418  11069  13:41:47                   ปกติ (เหลืองใส)   2        11006
# 39419  11069  14:17:46                   ปกติ (เหลืองใส)   0        11007
# 39420  11069  10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008
#
#         title age
# 191    นางสาว  47
# 192       นาง  41
# 193       นาง  55
# 194       นาย  66
# 195    นางสาว  50
# ...       ...  ..
# 39416  นางสาว  33
# 39417     นาย  28
# 39418     นาง  72
# 39419     นาง  48
# 39420     นาย  36
#
# [37406 rows x 11 columns]

# %% [markdown]
# ### ทำการเเก้ไขข้อมูลให้ถูกต้อง ในรูปแบบที่กำหนด

# %% [markdown]
# #### คอลัมน์ time

# %%
alldb_drop5['time'] = alldb_drop5['time'].replace(':','-', regex=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## ตาราง alldb.csv หลังจัดการข้อมูลแล้ว

# %%
alldb_drop5 # ดูตาราง alldb.csv หลังจัดการข้อมูลแล้ว
# Out:
#         user                                RowKey       date       phone  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30  iPhone12,3
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30  iPhone14,3
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# ...      ...                                   ...        ...         ...
# 39416  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 39417  26462                        cywpeqziic.png 2022-03-21   Vivo 1920
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22  iPhone13,4
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
# 39420  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site      time                             urine  ov PartitionKey  \
# 191    06307  14:46:08                   ปกติ (เหลืองใส)   4        00001
# 192    05328  15:27:45                   ปกติ (เหลืองใส)   4        00001
# 193    06302  10:16:46                   ปกติ (เหลืองใส)   3        00001
# 194    05059  12:26:38                   ปกติ (เหลืองใส)   3        00001
# 195    06334  14:57:41                   ปกติ (เหลืองใส)   0        00001
# ...      ...       ...                               ...  ..          ...
# 39416  11069  14:03:12                   ปกติ (เหลืองใส)   1        11003
# 39417  11069  13:59:04                   ปกติ (เหลืองใส)   2        11005
# 39418  11069  13:41:47                   ปกติ (เหลืองใส)   2        11006
# 39419  11069  14:17:46                   ปกติ (เหลืองใส)   0        11007
# 39420  11069  10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008
#
#         title age
# 191    นางสาว  47
# 192       นาง  41
# 193       นาง  55
# 194       นาย  66
# 195    นางสาว  50
# ...       ...  ..
# 39416  นางสาว  33
# 39417     นาย  28
# 39418     นาง  72
# 39419     นาง  48
# 39420     นาย  36
#
# [37406 rows x 11 columns]

# %% [markdown]
# ## จัดการข้อมูลหลัก ตาราง hospital_list.xlsx

# %%
hospital_list # แสดงข้อมูลตาราง hospital_list.xlsx
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %% [markdown]
# ### ตรวจสอบค่า Missing

# %%
hospital_list.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# hcode            False
# name              True
# zone_code        False
# zone_name         True
# provincecode      True
# province         False
# amphurcode        True
# amphur            True
# tamboncode        True
# tambon            True
# code4             True
# name5             True
# code9             True
# name10            True
# short_thai        True
# short_english     True
# dtype: bool

# %% [markdown]
# ### ใช้ .dropna ซึ่งจะใช้ตัดแถวข้อมูลที่มีค่า missing

# %%
h_drop = hospital_list.dropna() #ใช้ dropna เพื่อต้องการลบข้อมูลทั้งแถวออกเมื่อมีคอลัมน์ใดคอลัมน์หนึ่งเป็น NaN
h_drop
# Out:
#        hcode                                               name  zone_code  \
# 931    00933              โรงพยาบาลส่งเสริมสุขภาพตำบลสำโรงเหนือ          6
# 932    00934                โรงพยาบาลส่งเสริมสุขภาพตำบลบางเมือง          6
# 933    00935  โรงพยาบาลส่งเสริมสุขภาพตำบลเฉลิมพระเกียรติ บ้า...          6
# 934    00936               โรงพยาบาลส่งเสริมสุขภาพตำบลบางปูใหม่          6
# 935    00937                  โรงพยาบาลส่งเสริมสุขภาพตำบลแพรกษา          6
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 931          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 932          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 933          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 934          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 935          สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode      tambon  code4  \
# 931    เมืองสมุทรปราการ         2.0  สำโรงเหนือ   18.0
# 932    เมืองสมุทรปราการ         3.0    บางเมือง   18.0
# 933    เมืองสมุทรปราการ         3.0    บางเมือง   18.0
# 934    เมืองสมุทรปราการ         8.0   บางปูใหม่   18.0
# 935    เมืองสมุทรปราการ        10.0      แพรกษา   18.0
# ...                 ...         ...         ...    ...
# 17098    เมืองอุตรดิตถ์         1.0      ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0     กุยบุรี    8.0
# 17100           วัดเพลง         3.0     วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0      โพนข่า    8.0
# 17102             บางแพ         2.0     วังเย็น    8.0
#
#                              name5  code9     name10 short_thai short_english
# 931    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 932    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 933    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 934    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# 935    โรงพยาบาลส่งเสริมสุขภาพตำบล   10.0  1 ปฐมภูมิ         สป           SPK
# ...                            ...    ...        ...        ...           ...
# 17098     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102     ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [11798 rows x 16 columns]

# %%
h_drop.shape #ตรวจสอบขนาดของตารางใหม่
# Out:
# (11798, 16)

# %%
removes = hospital_list.shape[0] - h_drop.shape[0]
print(f'size before drop = {hospital_list.shape[0]}')
print(f'size after drop = {h_drop.shape[0]}')
print(f'% from drop = {(removes/hospital_list.shape[0])*100}')
 # จากการคำนวณพบว่ามีข้อมูลที่หายไปถึง 31% ดังนั้น จึงไม่สามารถใช้การ .dropna() ได ้
# Out:
# size before drop = 17103
# size after drop = 11798
# % from drop = 31.017950067239664

# %%
hospital_list[['name']] = hospital_list[['name']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list[['zone_name']] = hospital_list[['zone_name']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
p = hospital_list[['provincecode']].mean() #กำหนดให้ provincecode เป็นค่าเฉลี่ยของ provincecode
hospital_list[['provincecode']] = hospital_list[['provincecode']].fillna(p) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
a = hospital_list[['amphurcode']].mean() #กำหนดให้ amphurcode เป็นค่าเฉลี่ยของ amphurcode
hospital_list[['amphurcode']] = hospital_list[['amphurcode']].fillna(a) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['amphur']] = hospital_list[['amphur']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
t = hospital_list[['tamboncode']].mean() #กำหนดให้ tamboncode เป็นค่าเฉลี่ยของ tamboncode
hospital_list[['tamboncode']] = hospital_list[['tamboncode']].fillna(t) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['tambon']] = hospital_list[['tambon']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
c = hospital_list[['code4']].mean() #กำหนดให้ code4 เป็นค่าเฉลี่ยของ code4
hospital_list[['code4']] = hospital_list[['code4']].fillna(c) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['name5']] = hospital_list[['name5']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
c2 = hospital_list[['code9']].mean() #กำหนดให้ code9 เป็นค่าเฉลี่ยของ code9
hospital_list[['code9']] = hospital_list[['code9']].fillna(c2) #แทนค่าเฉลี่ยลงในข้อมูลที่ว่าง หรือเป็นค่า missing

# %%
hospital_list[['name10']] = hospital_list[['name10']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list[['short_thai']] = hospital_list[['short_thai']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list[['short_english']] = hospital_list[['short_english']].fillna('ไม่ระบุ') 
#แทนค่า Missing ด้วยคำว่า ไม่ระบุ

# %%
hospital_list.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# hcode            False
# name             False
# zone_code        False
# zone_name        False
# provincecode     False
# province         False
# amphurcode       False
# amphur           False
# tamboncode       False
# tambon           False
# code4            False
# name5            False
# code9            False
# name10           False
# short_thai       False
# short_english    False
# dtype: bool

# %% [markdown]
# ### ทำการเปลี่ยน type ของข้อมูลให้เป็น type ที่ถูกต้อง

# %%
hospital_list.dtypes # เช็คว่าข้อมูลมี่ความตรงกับที่ต้องการหรือไม่ ## ต้องการให้ hcode เป็น int
# Out:
# hcode             object
# name              object
# zone_code          int64
# zone_name         object
# provincecode     float64
# province          object
# amphurcode       float64
# amphur            object
# tamboncode       float64
# tambon            object
# code4            float64
# name5             object
# code9            float64
# name10            object
# short_thai        object
# short_english     object
# dtype: object

# %%
set(hospital_list['hcode']) # เพื่อดูข้อมูลทั้งหมดใน column hcode
# Out:
# {'03583',
#  '01917',
#  '02417',
#  '08972',
#  '10574',
#  '01195',
#  '09649',
#  '04989',
#  '05492',
#  '04103',
#  '02534',
#  '07354',
#  '05318',
#  '23578',
#  '07048',
#  '09843',
#  '21434',
#  '00124',
#  '06894',
#  '08943',
#  '00390',
#  '07244',
#  '04370',
#  '03010',
#  '07960',
#  '03941',
#  '15055',
#  '01045',
#  '24021',
#  '23065',
#  '08956',
#  '00375',
#  '02098',
#  '25163',
#  '06877',
#  '07488',
#  '24110',
#  '01249',
#  '11119',
#  '25112',
#  '25622',
#  '27776',
#  '99942',
#  '09757',
#  '28157',
#  '07001',
#  '01560',
#  '05268',
#  '06895',
#  '14094',
#  '09653',
#  '11444',
#  '22860',
#  '06047',
#  '26176',
#  '28017',
#  '02761',
#  '25131',
#  '19418',
#  '02245',
#  '06624',
#  '19436',
#  '24547',
#  '27044',
#  '07421',
#  '27727',
#  '05238',
#  '02693',
#  '00033',
#  '09250',
#  '09775',
#  '11193',
#  '01943',
#  '04339',
#  '23220',
#  '23728',
#  '04247',
#  '05192',
#  '01726',
#  '02876',
#  '03809',
#  '15189',
#  '23887',
#  '28230',
#  '01607',
#  '05614',
#  '10918',
#  '05158',
#  '14264',
#  '25007',
#  '24872',
#  '00122',
#  '04556',
#  '24603',
#  '25677',
#  '25808',
#  '26871',
#  '24411',
#  '00044',
#  '02512',
#  '05029',
#  '06421',
#  '01731',
#  '05880',


# %% [markdown]
# เเก้ไขให้มีข้อมูลที่ถูกต้อง
#
# โดยกำหนดให้ข้อมูลที่ไม่ใช่เลข 5 หลัก เท่ากับ ข้อมูลว่าง

# %%
hospital_list['hcode'].replace({'2475x':None,'2560x':None},inplace=True)

# %%
hospital_list_drop = hospital_list.dropna() # ทำการ drop ค่าว่างออก 
hospital_list_drop # แสดงผลลัพธ์
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5     code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อท           ATG
# ...                         ...       ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
#
# [17101 rows x 16 columns]

# %%
hospital_list_drop = hospital_list_drop[(hospital_list_drop['hcode'].astype(str).str.isdigit()) & (hospital_list_drop['hcode'].str.len() == 5 )] # เลือกข้อมูลที่เป็น 5 หลัก

# %%
hospital_list_drop
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5     code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อท           ATG
# ...                         ...       ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
#
# [17101 rows x 16 columns]

# %% [markdown]
# ## ตาราง hospital_list.xlsx หลังจัดการข้อมูลแล้ว

# %%
hospital_list_drop # ดูตาราง hospital_list.xlsx หลังจัดการข้อมูลแล้ว
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5     code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด  10.84859    ไม่ระบุ         อท           ATG
# ...                         ...       ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.  10.00000  1 ปฐมภูมิ         รบ           RBR
#
# [17101 rows x 16 columns]

# %% [markdown]
# # รวมข้อมูลทั้งสองตารางเข้าด้วยกัน
#
# ไฟล์ alldb.csv และ hospital_list.xlsx สามารถถูกเชื่อมโยงกันโดย site ในไฟล์ alldb.csv คือ hcode ในไฟล์ hospital_list.xlsx

# %%
merged = alldb_drop5.merge(hospital_list_drop,how='left',left_on='site',right_on='hcode') 
merged
# Out:
#         user                                RowKey       date       phone  \
# 0      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30  iPhone12,3
# 1      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30  iPhone14,3
# 2      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 3      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 4      28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# ...      ...                                   ...        ...         ...
# 37401  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 37402  26462                        cywpeqziic.png 2022-03-21   Vivo 1920
# 37403  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22  iPhone13,4
# 37404  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
# 37405  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site      time                             urine  ov PartitionKey  \
# 0      06307  14:46:08                   ปกติ (เหลืองใส)   4        00001
# 1      05328  15:27:45                   ปกติ (เหลืองใส)   4        00001
# 2      06302  10:16:46                   ปกติ (เหลืองใส)   3        00001
# 3      05059  12:26:38                   ปกติ (เหลืองใส)   3        00001
# 4      06334  14:57:41                   ปกติ (เหลืองใส)   0        00001
# ...      ...       ...                               ...  ..          ...
# 37401  11069  14:03:12                   ปกติ (เหลืองใส)   1        11003
# 37402  11069  13:59:04                   ปกติ (เหลืองใส)   2        11005
# 37403  11069  13:41:47                   ปกติ (เหลืองใส)   2        11006
# 37404  11069  14:17:46                   ปกติ (เหลืองใส)   0        11007
# 37405  11069  10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008
#
#         title  ... amphurcode     amphur tamboncode     tambon code4  \
# 0      นางสาว  ...        7.0      พิชัย        2.0   บ้านดารา  18.0
# 1         นาง  ...       18.0    ฆ้องชัย        3.0   โคกสะอาด  18.0
# 2         นาง  ...        5.0     ฟากท่า        4.0    สองห้อง  18.0
# 3         นาย  ...       10.0      นาดูน        6.0      หัวดง  18.0
# 4      นางสาว  ...        9.0  ทองแสนขัน        4.0     น้ำพี้  18.0
# ...       ...  ...        ...        ...        ...        ...   ...
# 37401  นางสาว  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37402     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37403     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37404     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37405     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         กส
# 2      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         มค
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# ...                            ...   ...                     ...        ...
# 37401               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37402               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37403               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37404               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37405               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 0                UTT
# 1                KSN
# 2                UTT
# 3                MKM
# 4                UTT
# ...              ...
# 37401            RET
# 37402            RET
# 37403            RET
# 37404            RET
# 37405            RET
#
# [37406 rows x 27 columns]

# %% [markdown]
# ## ตรวจสอบค่า Missing

# %%
merged.isnull().any() 
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# user             False
# RowKey           False
# date             False
# phone            False
# site             False
# time             False
# urine            False
# ov               False
# PartitionKey     False
# title            False
# age              False
# hcode            False
# name             False
# zone_code        False
# zone_name        False
# provincecode     False
# province         False
# amphurcode       False
# amphur           False
# tamboncode       False
# tambon           False
# code4            False
# name5            False
# code9            False
# name10           False
# short_thai       False
# short_english    False
# dtype: bool

# %% [markdown]
# ## ใช้ .dropna ซึ่งจะใช้ตัดแถวข้อมูลที่มีค่า missing

# %%
merged_drop = merged.dropna() #ใช้ dropna เพื่อต้องการลบข้อมูลทั้งแถวออกเมื่อมีคอลัมน์ใดคอลัมน์หนึ่งเป็น NaN
merged_drop
# Out:
#         user                                RowKey       date       phone  \
# 0      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30  iPhone12,3
# 1      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30  iPhone14,3
# 2      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 3      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 4      28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# ...      ...                                   ...        ...         ...
# 37401  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 37402  26462                        cywpeqziic.png 2022-03-21   Vivo 1920
# 37403  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22  iPhone13,4
# 37404  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
# 37405  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site      time                             urine  ov PartitionKey  \
# 0      06307  14:46:08                   ปกติ (เหลืองใส)   4        00001
# 1      05328  15:27:45                   ปกติ (เหลืองใส)   4        00001
# 2      06302  10:16:46                   ปกติ (เหลืองใส)   3        00001
# 3      05059  12:26:38                   ปกติ (เหลืองใส)   3        00001
# 4      06334  14:57:41                   ปกติ (เหลืองใส)   0        00001
# ...      ...       ...                               ...  ..          ...
# 37401  11069  14:03:12                   ปกติ (เหลืองใส)   1        11003
# 37402  11069  13:59:04                   ปกติ (เหลืองใส)   2        11005
# 37403  11069  13:41:47                   ปกติ (เหลืองใส)   2        11006
# 37404  11069  14:17:46                   ปกติ (เหลืองใส)   0        11007
# 37405  11069  10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008
#
#         title  ... amphurcode     amphur tamboncode     tambon code4  \
# 0      นางสาว  ...        7.0      พิชัย        2.0   บ้านดารา  18.0
# 1         นาง  ...       18.0    ฆ้องชัย        3.0   โคกสะอาด  18.0
# 2         นาง  ...        5.0     ฟากท่า        4.0    สองห้อง  18.0
# 3         นาย  ...       10.0      นาดูน        6.0      หัวดง  18.0
# 4      นางสาว  ...        9.0  ทองแสนขัน        4.0     น้ำพี้  18.0
# ...       ...  ...        ...        ...        ...        ...   ...
# 37401  นางสาว  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37402     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37403     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37404     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37405     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         กส
# 2      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         มค
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# ...                            ...   ...                     ...        ...
# 37401               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37402               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37403               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37404               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37405               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 0                UTT
# 1                KSN
# 2                UTT
# 3                MKM
# 4                UTT
# ...              ...
# 37401            RET
# 37402            RET
# 37403            RET
# 37404            RET
# 37405            RET
#
# [37406 rows x 27 columns]

# %%
merged_drop.shape #ตรวจสอบขนาดของตารางใหม่
# Out:
# (37406, 27)

# %%
removes = merged.shape[0] - merged_drop.shape[0]
print(f'size before drop = {merged.shape[0]}')
print(f'size after drop = {merged_drop.shape[0]}')
print(f'% from drop = {(removes/merged.shape[0])*100}')
 # จากการคำนวณพบว่ามีข้อมูลที่หายไปเพียงแค่ 0.195% ดังนั้น จึงสามารถใช้การ .dropna() ได ้
# Out:
# size before drop = 37406
# size after drop = 37406
# % from drop = 0.0

# %% [markdown]
# # ตารางข้อมูลที่จะนำมาใช้

# %%
merged_drop # แสดงผลลัพธ์
# Out:
#         user                                RowKey       date       phone  \
# 0      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30  iPhone12,3
# 1      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30  iPhone14,3
# 2      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 3      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 4      28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# ...      ...                                   ...        ...         ...
# 37401  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 37402  26462                        cywpeqziic.png 2022-03-21   Vivo 1920
# 37403  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22  iPhone13,4
# 37404  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
# 37405  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site      time                             urine  ov PartitionKey  \
# 0      06307  14:46:08                   ปกติ (เหลืองใส)   4        00001
# 1      05328  15:27:45                   ปกติ (เหลืองใส)   4        00001
# 2      06302  10:16:46                   ปกติ (เหลืองใส)   3        00001
# 3      05059  12:26:38                   ปกติ (เหลืองใส)   3        00001
# 4      06334  14:57:41                   ปกติ (เหลืองใส)   0        00001
# ...      ...       ...                               ...  ..          ...
# 37401  11069  14:03:12                   ปกติ (เหลืองใส)   1        11003
# 37402  11069  13:59:04                   ปกติ (เหลืองใส)   2        11005
# 37403  11069  13:41:47                   ปกติ (เหลืองใส)   2        11006
# 37404  11069  14:17:46                   ปกติ (เหลืองใส)   0        11007
# 37405  11069  10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008
#
#         title  ... amphurcode     amphur tamboncode     tambon code4  \
# 0      นางสาว  ...        7.0      พิชัย        2.0   บ้านดารา  18.0
# 1         นาง  ...       18.0    ฆ้องชัย        3.0   โคกสะอาด  18.0
# 2         นาง  ...        5.0     ฟากท่า        4.0    สองห้อง  18.0
# 3         นาย  ...       10.0      นาดูน        6.0      หัวดง  18.0
# 4      นางสาว  ...        9.0  ทองแสนขัน        4.0     น้ำพี้  18.0
# ...       ...  ...        ...        ...        ...        ...   ...
# 37401  นางสาว  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37402     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37403     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37404     นาง  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37405     นาย  ...       10.0    เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         กส
# 2      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         มค
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# ...                            ...   ...                     ...        ...
# 37401               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37402               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37403               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37404               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37405               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 0                UTT
# 1                KSN
# 2                UTT
# 3                MKM
# 4                UTT
# ...              ...
# 37401            RET
# 37402            RET
# 37403            RET
# 37404            RET
# 37405            RET
#
# [37406 rows x 27 columns]

# %%
merged_drop.isnull().any()
# Out:
# user             False
# RowKey           False
# date             False
# phone            False
# site             False
# time             False
# urine            False
# ov               False
# PartitionKey     False
# title            False
# age              False
# hcode            False
# name             False
# zone_code        False
# zone_name        False
# provincecode     False
# province         False
# amphurcode       False
# amphur           False
# tamboncode       False
# tambon           False
# code4            False
# name5            False
# code9            False
# name10           False
# short_thai       False
# short_english    False
# dtype: bool

# %% [markdown]
# ## จำนวนการตรวจในแต่ละพื้นที่

# %%
Province = merged_drop.groupby('province').count()
Province
# Out:
#               user  RowKey   date  phone   site   time  urine     ov  \
# province
# กาฬสินธุ์     7814    7814   7814   7814   7814   7814   7814   7814
# ขอนแก่น       4242    4242   4242   4242   4242   4242   4242   4242
# นครพนม           5       5      5      5      5      5      5      5
# นครราชสีมา       1       1      1      1      1      1      1      1
# มหาสารคาม     8896    8896   8896   8896   8896   8896   8896   8896
# มุกดาหาร         2       2      2      2      2      2      2      2
# ร้อยเอ็ด     13656   13656  13656  13656  13656  13656  13656  13656
# ลำปาง            1       1      1      1      1      1      1      1
# ศรีสะเกษ         3       3      3      3      3      3      3      3
# สกลนคร           6       6      6      6      6      6      6      6
# อุดรธานี         1       1      1      1      1      1      1      1
# อุตรดิตถ์     2778    2778   2778   2778   2778   2778   2778   2778
# อุบลราชธานี      1       1      1      1      1      1      1      1
#
#              PartitionKey  title  ...  amphurcode  amphur  tamboncode  tambon  \
# province                          ...
# กาฬสินธุ์            7814   7814  ...        7814    7814        7814    7814
# ขอนแก่น              4242   4242  ...        4242    4242        4242    4242
# นครพนม                  5      5  ...           5       5           5       5
# นครราชสีมา              1      1  ...           1       1           1       1
# มหาสารคาม            8896   8896  ...        8896    8896        8896    8896
# มุกดาหาร                2      2  ...           2       2           2       2
# ร้อยเอ็ด            13656  13656  ...       13656   13656       13656   13656
# ลำปาง                   1      1  ...           1       1           1       1
# ศรีสะเกษ                3      3  ...           3       3           3       3
# สกลนคร                  6      6  ...           6       6           6       6
# อุดรธานี                1      1  ...           1       1           1       1
# อุตรดิตถ์            2778   2778  ...        2778    2778        2778    2778
# อุบลราชธานี             1      1  ...           1       1           1       1
#
#              code4  name5  code9  name10  short_thai  short_english
# province
# กาฬสินธุ์     7814   7814   7814    7814        7814           7814
# ขอนแก่น       4242   4242   4242    4242        4242           4242
# นครพนม           5      5      5       5           5              5
# นครราชสีมา       1      1      1       1           1              1
# มหาสารคาม     8896   8896   8896    8896        8896           8896
# มุกดาหาร         2      2      2       2           2              2
# ร้อยเอ็ด     13656  13656  13656   13656       13656          13656
# ลำปาง            1      1      1       1           1              1
# ศรีสะเกษ         3      3      3       3           3              3
# สกลนคร           6      6      6       6           6              6
# อุดรธานี         1      1      1       1           1              1
# อุตรดิตถ์     2778   2778   2778    2778        2778           2778
# อุบลราชธานี      1      1      1       1           1              1
#
# [13 rows x 26 columns]

# %%
Province_new = Province.iloc[:,:1]
Province_new
# Out:
#               user
# province
# กาฬสินธุ์     7814
# ขอนแก่น       4242
# นครพนม           5
# นครราชสีมา       1
# มหาสารคาม     8896
# มุกดาหาร         2
# ร้อยเอ็ด     13656
# ลำปาง            1
# ศรีสะเกษ         3
# สกลนคร           6
# อุดรธานี         1
# อุตรดิตถ์     2778
# อุบลราชธานี      1

# %%
P_noindex = Province_new.reset_index()
P_noindex
# Out:
#        province   user
# 0     กาฬสินธุ์   7814
# 1       ขอนแก่น   4242
# 2        นครพนม      5
# 3    นครราชสีมา      1
# 4     มหาสารคาม   8896
# 5      มุกดาหาร      2
# 6      ร้อยเอ็ด  13656
# 7         ลำปาง      1
# 8      ศรีสะเกษ      3
# 9        สกลนคร      6
# 10     อุดรธานี      1
# 11    อุตรดิตถ์   2778
# 12  อุบลราชธานี      1

# %%
pv = {'user':'จำนวนการตรวจในแต่ละพื้นที่'}
# call rename () method
P_noindex.rename(columns=pv,
          inplace=True)
P_noindex
# Out:
#        province  จำนวนการตรวจในแต่ละพื้นที่
# 0     กาฬสินธุ์                        7814
# 1       ขอนแก่น                        4242
# 2        นครพนม                           5
# 3    นครราชสีมา                           1
# 4     มหาสารคาม                        8896
# 5      มุกดาหาร                           2
# 6      ร้อยเอ็ด                       13656
# 7         ลำปาง                           1
# 8      ศรีสะเกษ                           3
# 9        สกลนคร                           6
# 10     อุดรธานี                           1
# 11    อุตรดิตถ์                        2778
# 12  อุบลราชธานี                           1

# %% [markdown]
# ## จำนวนที่พบโรค

# %% [markdown]
# ### ระดับ 0

# %%
ov_0 = merged_drop[merged_drop['ov']== 0]
ov_0
# Out:
#         user                                RowKey       date       phone  \
# 4      28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402 2022-03-31  iPhone13,3
# 8      19911  22E333B1-A8D4-4FCB-8304-7BD2C3D9C94A 2022-03-30  iPhone12,5
# 9      99771  267232EA-5B0D-4783-8449-16687A62C5B7 2022-03-22  iPhone10,6
# 13     14360  41AE352F-77A0-4D26-B39C-6A09B39576BA 2022-03-31   iPhone8,2
# 17     27096  4D1F5F3E-E557-4F64-BEB7-D4FBCADFA43F 2022-03-30  iPhone14,5
# ...      ...                                   ...        ...         ...
# 37394  26462                        vcubzchjxv.png 2022-03-21   Vivo 1920
# 37396  26462  AD576EF3-4128-4DCD-93CB-63494C69F326 2022-03-22  iPhone13,4
# 37397  26462                        qukpkgoxfp.png 2022-03-21   Vivo 1920
# 37399  26462                        dghzdcrtay.png 2022-03-21   Vivo 1920
# 37404  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC 2022-03-21  iPhone13,4
#
#         site      time            urine  ov PartitionKey   title  ...  \
# 4      06334  14:57:41  ปกติ (เหลืองใส)   0        00001  นางสาว  ...
# 8      06319  09:32:46  ปกติ (เหลืองใส)   0        00001     นาย  ...
# 9      05396  10:35:33  ปกติ (เหลืองใส)   0        00001  นางสาว  ...
# 13     04405  14:11:05  ปกติ (เหลืองใส)   0        00001  นางสาว  ...
# 17     11160  14:56:46  ปกติ (เหลืองใส)   0        00001     นาง  ...
# ...      ...       ...              ...  ..          ...     ...  ...
# 37394  11069  14:18:41  ปกติ (เหลืองใส)   0        10995     นาย  ...
# 37396  11069  13:39:56  ปกติ (เหลืองใส)   0        10997     นาง  ...
# 37397  11069  11:54:17  ปกติ (เหลืองใส)   0        10998     นาง  ...
# 37399  11069  11:51:32          มีตะกอน   0        11000     นาย  ...
# 37404  11069  14:17:46  ปกติ (เหลืองใส)   0        11007     นาง  ...
#
#       amphurcode       amphur tamboncode     tambon code4  \
# 4            9.0    ทองแสนขัน        4.0     น้ำพี้  18.0
# 8            7.0        พิชัย       11.0      นายาง  18.0
# 9           10.0       คำม่วง        9.0    เนินยาง  18.0
# 13          15.0  หนองสองห้อง        9.0     หันโจด  18.0
# 17           4.0       น้ำปาด        1.0      แสนตอ   7.0
# ...          ...          ...        ...        ...   ...
# 37394       10.0      เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37396       10.0      เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37397       10.0      เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37399       10.0      เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37404       10.0      เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 8      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 9      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         กส
# 13     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         ขก
# 17                  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         อต
# ...                            ...   ...                     ...        ...
# 37394               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37396               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37397               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37399               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37404               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 4                UTT
# 8                UTT
# 9                KSN
# 13               KKN
# 17               UTT
# ...              ...
# 37394            RET
# 37396            RET
# 37397            RET
# 37399            RET
# 37404            RET
#
# [21021 rows x 27 columns]

# %%
ov_0 = ov_0.groupby('province').count()
ov_0
# Out:
#              user  RowKey  date  phone  site  time  urine    ov  PartitionKey  \
# province
# กาฬสินธุ์    5190    5190  5190   5190  5190  5190   5190  5190          5190
# ขอนแก่น      3315    3315  3315   3315  3315  3315   3315  3315          3315
# นครพนม          2       2     2      2     2     2      2     2             2
# นครราชสีมา      1       1     1      1     1     1      1     1             1
# มหาสารคาม    3960    3960  3960   3960  3960  3960   3960  3960          3960
# มุกดาหาร        2       2     2      2     2     2      2     2             2
# ร้อยเอ็ด     7029    7029  7029   7029  7029  7029   7029  7029          7029
# ศรีสะเกษ        1       1     1      1     1     1      1     1             1
# สกลนคร          3       3     3      3     3     3      3     3             3
# อุตรดิตถ์    1517    1517  1517   1517  1517  1517   1517  1517          1517
# อุบลราชธานี     1       1     1      1     1     1      1     1             1
#
#              title  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province            ...
# กาฬสินธุ์     5190  ...        5190    5190        5190    5190   5190   5190
# ขอนแก่น       3315  ...        3315    3315        3315    3315   3315   3315
# นครพนม           2  ...           2       2           2       2      2      2
# นครราชสีมา       1  ...           1       1           1       1      1      1
# มหาสารคาม     3960  ...        3960    3960        3960    3960   3960   3960
# มุกดาหาร         2  ...           2       2           2       2      2      2
# ร้อยเอ็ด      7029  ...        7029    7029        7029    7029   7029   7029
# ศรีสะเกษ         1  ...           1       1           1       1      1      1
# สกลนคร           3  ...           3       3           3       3      3      3
# อุตรดิตถ์     1517  ...        1517    1517        1517    1517   1517   1517
# อุบลราชธานี      1  ...           1       1           1       1      1      1
#
#              code9  name10  short_thai  short_english
# province
# กาฬสินธุ์     5190    5190        5190           5190
# ขอนแก่น       3315    3315        3315           3315
# นครพนม           2       2           2              2
# นครราชสีมา       1       1           1              1
# มหาสารคาม     3960    3960        3960           3960
# มุกดาหาร         2       2           2              2
# ร้อยเอ็ด      7029    7029        7029           7029
# ศรีสะเกษ         1       1           1              1
# สกลนคร           3       3           3              3
# อุตรดิตถ์     1517    1517        1517           1517
# อุบลราชธานี      1       1           1              1
#
# [11 rows x 26 columns]

# %%
ov_0_new = ov_0.iloc[:,:1]
ov_0_new
# Out:
#              user
# province
# กาฬสินธุ์    5190
# ขอนแก่น      3315
# นครพนม          2
# นครราชสีมา      1
# มหาสารคาม    3960
# มุกดาหาร        2
# ร้อยเอ็ด     7029
# ศรีสะเกษ        1
# สกลนคร          3
# อุตรดิตถ์    1517
# อุบลราชธานี     1

# %%
ov_0_noindex = ov_0_new.reset_index()
ov_0_noindex
# Out:
#        province  user
# 0     กาฬสินธุ์  5190
# 1       ขอนแก่น  3315
# 2        นครพนม     2
# 3    นครราชสีมา     1
# 4     มหาสารคาม  3960
# 5      มุกดาหาร     2
# 6      ร้อยเอ็ด  7029
# 7      ศรีสะเกษ     1
# 8        สกลนคร     3
# 9     อุตรดิตถ์  1517
# 10  อุบลราชธานี     1

# %%
o0 = {'user':'จำนวนที่พบโรค ระดับ 0'}
# call rename () method
ov_0_noindex.rename(columns=o0,
          inplace=True)
ov_0_noindex
# Out:
#        province  จำนวนที่พบโรค ระดับ 0
# 0     กาฬสินธุ์                   5190
# 1       ขอนแก่น                   3315
# 2        นครพนม                      2
# 3    นครราชสีมา                      1
# 4     มหาสารคาม                   3960
# 5      มุกดาหาร                      2
# 6      ร้อยเอ็ด                   7029
# 7      ศรีสะเกษ                      1
# 8        สกลนคร                      3
# 9     อุตรดิตถ์                   1517
# 10  อุบลราชธานี                      1

# %% [markdown]
# ### ระดับ 1

# %%
ov_1 = merged_drop[merged_drop['ov']== 1]
ov_1
# Out:
#         user                                RowKey       date       phone  \
# 15     24986  44E5D0C4-9195-47FC-82C3-CF9A711D85AB 2022-03-28  iPhone14,3
# 27     08370  6E4E96B0-5DE4-456F-8088-A1FEF6E3F468 2022-03-23  iPhone10,5
# 31     06964  7667F96F-0ACA-4111-9ABD-54BFE320009D 2022-03-29  iPhone12,1
# 34     71152  7A9B5C50-E7CC-4EF4-9E72-7D018B488040 2022-03-10  iPhone13,2
# 37     06283  83B0AD8E-AF6A-4D2F-A321-B9CF22915090 2022-03-28  iPhone13,2
# ...      ...                                   ...        ...         ...
# 37379  26462                        fvygcngevl.png 2022-03-21   Vivo 1920
# 37383  26462                        jdmhexxudc.png 2022-03-21   Vivo 1920
# 37398  26462  10CBBBC5-3BAC-4927-93B1-24918834B166 2022-03-22  iPhone13,4
# 37401  26462                        ieotqfnqcq.png 2022-03-22   Vivo 1920
# 37405  26462                        vdxxgljykj.png 2022-03-21  Vivo V2050
#
#         site      time                             urine  ov PartitionKey  \
# 15     06278  11:49:13                   ปกติ (เหลืองใส)   1        00001
# 27     13966  10:42:14                   ปกติ (เหลืองใส)   1        00001
# 31     06286  10:58:45                   ปกติ (เหลืองใส)   1        00001
# 34     05327  11:16:06                   ปกติ (เหลืองใส)   1        00001
# 37     06283  14:29:40                   ปกติ (เหลืองใส)   1        00001
# ...      ...       ...                               ...  ..          ...
# 37379  11069  10:29:01                   ปกติ (เหลืองใส)   1        10980
# 37383  11069  10:54:05  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        10984
# 37398  11069  14:01:18                   ปกติ (เหลืองใส)   1        10999
# 37401  11069  14:03:12                   ปกติ (เหลืองใส)   1        11003
# 37405  11069  10:54:49  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008
#
#         title  ... amphurcode    amphur tamboncode     tambon code4  \
# 15        นาย  ...        3.0    ท่าปลา        2.0     หาดล้า  18.0
# 27     นางสาว  ...       14.0  ห้วยผึ้ง        2.0    ไค้นุ่น  18.0
# 31        นาง  ...        3.0    ท่าปลา        6.0     ท่าแฝก  18.0
# 34        นาง  ...       18.0   ฆ้องชัย        3.0   โคกสะอาด  18.0
# 37        นาย  ...        3.0    ท่าปลา        5.0    น้ำหมัน  18.0
# ...       ...  ...        ...       ...        ...        ...   ...
# 37379     นาย  ...       10.0   เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37383     นาง  ...       10.0   เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37398     นาง  ...       10.0   เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37401  นางสาว  ...       10.0   เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37405     นาย  ...       10.0   เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 15     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 27     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         กส
# 31     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 34     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         กส
# 37     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# ...                            ...   ...                     ...        ...
# 37379               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37383               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37398               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37401               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37405               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 15               UTT
# 27               KSN
# 31               UTT
# 34               KSN
# 37               UTT
# ...              ...
# 37379            RET
# 37383            RET
# 37398            RET
# 37401            RET
# 37405            RET
#
# [7082 rows x 27 columns]

# %%
ov_1 = ov_1.groupby('province').count()
ov_1
# Out:
#            user  RowKey  date  phone  site  time  urine    ov  PartitionKey  \
# province
# กาฬสินธุ์   916     916   916    916   916   916    916   916           916
# ขอนแก่น     551     551   551    551   551   551    551   551           551
# นครพนม        2       2     2      2     2     2      2     2             2
# มหาสารคาม  2104    2104  2104   2104  2104  2104   2104  2104          2104
# ร้อยเอ็ด   3051    3051  3051   3051  3051  3051   3051  3051          3051
# ศรีสะเกษ      1       1     1      1     1     1      1     1             1
# สกลนคร        3       3     3      3     3     3      3     3             3
# อุดรธานี      1       1     1      1     1     1      1     1             1
# อุตรดิตถ์   453     453   453    453   453   453    453   453           453
#
#            title  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province          ...
# กาฬสินธุ์    916  ...         916     916         916     916    916    916
# ขอนแก่น      551  ...         551     551         551     551    551    551
# นครพนม         2  ...           2       2           2       2      2      2
# มหาสารคาม   2104  ...        2104    2104        2104    2104   2104   2104
# ร้อยเอ็ด    3051  ...        3051    3051        3051    3051   3051   3051
# ศรีสะเกษ       1  ...           1       1           1       1      1      1
# สกลนคร         3  ...           3       3           3       3      3      3
# อุดรธานี       1  ...           1       1           1       1      1      1
# อุตรดิตถ์    453  ...         453     453         453     453    453    453
#
#            code9  name10  short_thai  short_english
# province
# กาฬสินธุ์    916     916         916            916
# ขอนแก่น      551     551         551            551
# นครพนม         2       2           2              2
# มหาสารคาม   2104    2104        2104           2104
# ร้อยเอ็ด    3051    3051        3051           3051
# ศรีสะเกษ       1       1           1              1
# สกลนคร         3       3           3              3
# อุดรธานี       1       1           1              1
# อุตรดิตถ์    453     453         453            453
#
# [9 rows x 26 columns]

# %%
ov_1_new = ov_1.iloc[:,:1]
ov_1_new
# Out:
#            user
# province
# กาฬสินธุ์   916
# ขอนแก่น     551
# นครพนม        2
# มหาสารคาม  2104
# ร้อยเอ็ด   3051
# ศรีสะเกษ      1
# สกลนคร        3
# อุดรธานี      1
# อุตรดิตถ์   453

# %%
ov_1_noindex = ov_1_new.reset_index()
ov_1_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์   916
# 1    ขอนแก่น   551
# 2     นครพนม     2
# 3  มหาสารคาม  2104
# 4   ร้อยเอ็ด  3051
# 5   ศรีสะเกษ     1
# 6     สกลนคร     3
# 7   อุดรธานี     1
# 8  อุตรดิตถ์   453

# %%
o1 = {'user':'จำนวนที่พบโรค ระดับ 1'}
# call rename () method
ov_1_noindex.rename(columns=o1,
          inplace=True)
ov_1_noindex
# Out:
#     province  จำนวนที่พบโรค ระดับ 1
# 0  กาฬสินธุ์                    916
# 1    ขอนแก่น                    551
# 2     นครพนม                      2
# 3  มหาสารคาม                   2104
# 4   ร้อยเอ็ด                   3051
# 5   ศรีสะเกษ                      1
# 6     สกลนคร                      3
# 7   อุดรธานี                      1
# 8  อุตรดิตถ์                    453

# %% [markdown]
# ### ระดับ 2

# %%
ov_2 = merged_drop[merged_drop['ov']== 2]
ov_2
# Out:
#         user                                RowKey       date         phone  \
# 6      06277  1DDA8B23-D1EA-4E15-AE70-1E7FE53733B6 2022-03-25    iPhone14,3
# 12     18041  3FBB8FE8-F3EE-4307-8E01-406D7A1B2488 2022-03-28    iPhone14,3
# 19     00001  540553CD-1EAB-4252-A64E-F96A8390CE10 2022-03-28      iPad13,6
# 20     74891  594A7093-AB5F-4A64-8B74-E336ED81A444 2022-04-01    iPhone12,8
# 22     40059  5F8D255F-B0F5-4CE5-9607-7916E394173D 2022-03-18      iPad13,1
# ...      ...                                   ...        ...           ...
# 37366  26462                        wgxurysjec.png 2022-03-22  OPPO CPH1819
# 37367  26462                        vanquopswi.png 2022-03-22    Vivo V2050
# 37395  26462  3340619E-D3F4-4090-B3D0-B6CDF1D9F370 2022-03-21    iPhone13,4
# 37402  26462                        cywpeqziic.png 2022-03-21     Vivo 1920
# 37403  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7 2022-03-22    iPhone13,4
#
#         site      time            urine  ov PartitionKey title  ...  \
# 6      06277  10:13:51  ปกติ (เหลืองใส)   2        00001   นาย  ...
# 12     11158  10:12:10  ปกติ (เหลืองใส)   2        00001   นาง  ...
# 19     10360  12:24:15  ปกติ (เหลืองใส)   2        00001   นาย  ...
# 20     05055  15:15:35          มีตะกอน   2        00001   นาง  ...
# 22     05052  11:36:13   ใสเป็นน้ำเปล่า   2        00001   นาง  ...
# ...      ...       ...              ...  ..          ...   ...  ...
# 37366  11069  09:13:07             ขุ่น   2        10968   นาย  ...
# 37367  11069  09:48:29  ปกติ (เหลืองใส)   2        10969   นาย  ...
# 37395  11069  13:58:41          มีตะกอน   2        10996   นาง  ...
# 37402  11069  13:59:04  ปกติ (เหลืองใส)   2        11005   นาย  ...
# 37403  11069  13:41:47  ปกติ (เหลืองใส)   2        11006   นาง  ...
#
#       amphurcode   amphur tamboncode     tambon code4  \
# 6            3.0   ท่าปลา        2.0     หาดล้า  18.0
# 12           2.0     ตรอน        2.0   บ้านแก่ง   7.0
# 19           4.0   น้ำปาด        5.0     น้ำไผ่  18.0
# 20          10.0    นาดูน        4.0      ดงบัง  18.0
# 22          10.0    นาดูน        2.0    หนองไผ่  18.0
# ...          ...      ...        ...        ...   ...
# 37366       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37367       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37395       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37402       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37403       10.0  เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 6      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 12                  โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         อต
# 19     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 20     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         มค
# 22     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         มค
# ...                            ...   ...                     ...        ...
# 37366               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37367               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37395               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37402               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37403               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 6                UTT
# 12               UTT
# 19               UTT
# 20               MKM
# 22               MKM
# ...              ...
# 37366            RET
# 37367            RET
# 37395            RET
# 37402            RET
# 37403            RET
#
# [3520 rows x 27 columns]

# %%
ov_2 = ov_2.groupby('province').count()
ov_2
# Out:
#            user  RowKey  date  phone  site  time  urine    ov  PartitionKey  \
# province
# กาฬสินธุ์   541     541   541    541   541   541    541   541           541
# ขอนแก่น     164     164   164    164   164   164    164   164           164
# มหาสารคาม  1183    1183  1183   1183  1183  1183   1183  1183          1183
# ร้อยเอ็ด   1396    1396  1396   1396  1396  1396   1396  1396          1396
# ลำปาง         1       1     1      1     1     1      1     1             1
# ศรีสะเกษ      1       1     1      1     1     1      1     1             1
# อุตรดิตถ์   234     234   234    234   234   234    234   234           234
#
#            title  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province          ...
# กาฬสินธุ์    541  ...         541     541         541     541    541    541
# ขอนแก่น      164  ...         164     164         164     164    164    164
# มหาสารคาม   1183  ...        1183    1183        1183    1183   1183   1183
# ร้อยเอ็ด    1396  ...        1396    1396        1396    1396   1396   1396
# ลำปาง          1  ...           1       1           1       1      1      1
# ศรีสะเกษ       1  ...           1       1           1       1      1      1
# อุตรดิตถ์    234  ...         234     234         234     234    234    234
#
#            code9  name10  short_thai  short_english
# province
# กาฬสินธุ์    541     541         541            541
# ขอนแก่น      164     164         164            164
# มหาสารคาม   1183    1183        1183           1183
# ร้อยเอ็ด    1396    1396        1396           1396
# ลำปาง          1       1           1              1
# ศรีสะเกษ       1       1           1              1
# อุตรดิตถ์    234     234         234            234
#
# [7 rows x 26 columns]

# %%
ov_2_new = ov_2.iloc[:,:1]
ov_2_new
# Out:
#            user
# province
# กาฬสินธุ์   541
# ขอนแก่น     164
# มหาสารคาม  1183
# ร้อยเอ็ด   1396
# ลำปาง         1
# ศรีสะเกษ      1
# อุตรดิตถ์   234

# %%
ov_2_noindex = ov_2_new.reset_index()
ov_2_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์   541
# 1    ขอนแก่น   164
# 2  มหาสารคาม  1183
# 3   ร้อยเอ็ด  1396
# 4      ลำปาง     1
# 5   ศรีสะเกษ     1
# 6  อุตรดิตถ์   234

# %%
o2 = {'user':'จำนวนที่พบโรค ระดับ 2'}
# call rename () method
ov_2_noindex.rename(columns=o2,
          inplace=True)
ov_2_noindex
# Out:
#     province  จำนวนที่พบโรค ระดับ 2
# 0  กาฬสินธุ์                    541
# 1    ขอนแก่น                    164
# 2  มหาสารคาม                   1183
# 3   ร้อยเอ็ด                   1396
# 4      ลำปาง                      1
# 5   ศรีสะเกษ                      1
# 6  อุตรดิตถ์                    234

# %% [markdown]
# ### ระดับ 3

# %%
ov_3 = merged_drop[merged_drop['ov']== 3]
ov_3
# Out:
#         user                                RowKey       date       phone  \
# 2      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30  iPhone13,4
# 3      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   iPhone9,4
# 5      41340  1C640780-7513-43C0-B1E4-4A535DA468F3 2022-03-30  iPhone14,5
# 16     16085  49A9B05F-9B2F-49B9-99D7-CC3A60836EE1 2022-03-30  iPhone13,2
# 18     60847  52421C45-3625-4E62-B681-158CF7049DC7 2022-03-28  iPhone14,3
# ...      ...                                   ...        ...         ...
# 37324  12576                        gitvjybizk.png 2022-03-09   Vivo 1938
# 37329  12576                        tanpttgcgs.png 2022-03-09   Vivo 1938
# 37346  89681  EF02B947-21AE-4F27-8B48-3B48967B3D7D 2022-03-18  iPhone13,4
# 37363  26462                        pnqumypemv.png 2022-03-22  Vivo V2050
# 37381  10982  D713CB5A-AE59-4FA7-9387-39C0B766120A 2022-03-21  iPhone13,4
#
#         site      time            urine  ov PartitionKey   title  ...  \
# 2      06302  10:16:46  ปกติ (เหลืองใส)   3        00001     นาง  ...
# 3      05059  12:26:38  ปกติ (เหลืองใส)   3        00001     นาย  ...
# 5      06288  10:28:02  ปกติ (เหลืองใส)   3        00001  นางสาว  ...
# 16     06299  13:11:51  ปกติ (เหลืองใส)   3        00001     นาง  ...
# 18     06298  10:23:45  ปกติ (เหลืองใส)   3        00001     นาย  ...
# ...      ...       ...              ...  ..          ...     ...  ...
# 37324  11057  15:51:03  ปกติ (เหลืองใส)   3        09016     นาย  ...
# 37329  11057  15:52:57  ปกติ (เหลืองใส)   3        09018     นาง  ...
# 37346  11070  17:40:29  ปกติ (เหลืองใส)   3        09031     นาย  ...
# 37363  11069  09:49:16  ปกติ (เหลืองใส)   3        10965  นางสาว  ...
# 37381  11069  10:30:00  ปกติ (เหลืองใส)   3        10982    น.ส.  ...
#
#       amphurcode          amphur tamboncode     tambon code4  \
# 2            5.0          ฟากท่า        4.0    สองห้อง  18.0
# 3           10.0           นาดูน        6.0      หัวดง  18.0
# 5            3.0          ท่าปลา        7.0     นางพญา  18.0
# 16           5.0          ฟากท่า        2.0     สองคอน  18.0
# 18           4.0          น้ำปาด        6.0   ห้วยมุ่น  18.0
# ...          ...             ...        ...        ...   ...
# 37324        8.0  พยัคฆภูมิพิสัย        1.0     ปะหลาน   7.0
# 37329        8.0  พยัคฆภูมิพิสัย        1.0     ปะหลาน   7.0
# 37346       11.0      สุวรรณภูมิ        1.0      สระคู   7.0
# 37363       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37381       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 2      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         มค
# 5      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 16     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 18     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# ...                            ...   ...                     ...        ...
# 37324               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         มค
# 37329               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         มค
# 37346               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37363               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37381               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 2                UTT
# 3                MKM
# 5                UTT
# 16               UTT
# 18               UTT
# ...              ...
# 37324            MKM
# 37329            MKM
# 37346            RET
# 37363            RET
# 37381            RET
#
# [2953 rows x 27 columns]

# %%
ov_3 = ov_3.groupby('province').count()
ov_3
# Out:
#            user  RowKey  date  phone  site  time  urine    ov  PartitionKey  \
# province
# กาฬสินธุ์   522     522   522    522   522   522    522   522           522
# ขอนแก่น     125     125   125    125   125   125    125   125           125
# นครพนม        1       1     1      1     1     1      1     1             1
# มหาสารคาม   884     884   884    884   884   884    884   884           884
# ร้อยเอ็ด   1163    1163  1163   1163  1163  1163   1163  1163          1163
# อุตรดิตถ์   258     258   258    258   258   258    258   258           258
#
#            title  ...  amphurcode  amphur  tamboncode  tambon  code4  name5  \
# province          ...
# กาฬสินธุ์    522  ...         522     522         522     522    522    522
# ขอนแก่น      125  ...         125     125         125     125    125    125
# นครพนม         1  ...           1       1           1       1      1      1
# มหาสารคาม    884  ...         884     884         884     884    884    884
# ร้อยเอ็ด    1163  ...        1163    1163        1163    1163   1163   1163
# อุตรดิตถ์    258  ...         258     258         258     258    258    258
#
#            code9  name10  short_thai  short_english
# province
# กาฬสินธุ์    522     522         522            522
# ขอนแก่น      125     125         125            125
# นครพนม         1       1           1              1
# มหาสารคาม    884     884         884            884
# ร้อยเอ็ด    1163    1163        1163           1163
# อุตรดิตถ์    258     258         258            258
#
# [6 rows x 26 columns]

# %%
ov_3_new = ov_3.iloc[:,:1]
ov_3_new
# Out:
#            user
# province
# กาฬสินธุ์   522
# ขอนแก่น     125
# นครพนม        1
# มหาสารคาม   884
# ร้อยเอ็ด   1163
# อุตรดิตถ์   258

# %%
ov_3_noindex = ov_3_new.reset_index()
ov_3_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์   522
# 1    ขอนแก่น   125
# 2     นครพนม     1
# 3  มหาสารคาม   884
# 4   ร้อยเอ็ด  1163
# 5  อุตรดิตถ์   258

# %%
o3 = {'user':'จำนวนที่พบโรค ระดับ 3'}
# call rename () method
ov_3_noindex.rename(columns=o3,
          inplace=True)
ov_3_noindex
# Out:
#     province  จำนวนที่พบโรค ระดับ 3
# 0  กาฬสินธุ์                    522
# 1    ขอนแก่น                    125
# 2     นครพนม                      1
# 3  มหาสารคาม                    884
# 4   ร้อยเอ็ด                   1163
# 5  อุตรดิตถ์                    258

# %% [markdown]
# ### ระดับ 4

# %%
ov_4 = merged_drop[merged_drop['ov']== 4]
ov_4
# Out:
#         user                                RowKey       date         phone  \
# 0      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30    iPhone12,3
# 1      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30    iPhone14,3
# 7      22119  1FBE544D-7313-43EA-95EF-91DAD0513808 2022-04-01     iPhone8,1
# 10     89195  27A826ED-D57D-4386-8A3C-9CFD13297B8B 2022-03-30     iPhone9,3
# 11     59476  2AAA9DE2-24E6-4F41-B02E-0CB610C906C6 2022-03-25     iPhone9,4
# ...      ...                                   ...        ...           ...
# 37302  12576                        mmttpolskc.png 2022-03-09     Vivo 1938
# 37359  26462  6C55B69E-8E4C-46B0-B0D7-4754A529EE3C 2022-03-21    iPhone13,4
# 37374  26462  5CB6F5EB-324D-448C-84AD-C9D48B23684E 2022-03-22    iPhone13,4
# 37385  26462                        iwwwnyrmtz.png 2022-03-22  OPPO CPH1819
# 37400  26462                        rryhjijyje.png 2022-03-21    Vivo V2050
#
#         site      time              urine  ov PartitionKey   title  ...  \
# 0      06307  14:46:08    ปกติ (เหลืองใส)   4        00001  นางสาว  ...
# 1      05328  15:27:45    ปกติ (เหลืองใส)   4        00001     นาง  ...
# 7      06261  15:40:17    ปกติ (เหลืองใส)   4        00001     นาง  ...
# 10     06267  10:08:32    ปกติ (เหลืองใส)   4        00001     นาง  ...
# 11     05000  11:14:25  สีฟ้า หรือน้ำเงิน   4        00001     นาง  ...
# ...      ...       ...                ...  ..          ...     ...  ...
# 37302  11057  10:00:22               ขุ่น   4        09005     นาง  ...
# 37359  11069  10:08:34    ปกติ (เหลืองใส)   4        10961     นาง  ...
# 37374  11069  14:04:13    ปกติ (เหลืองใส)   4        10975     นาง  ...
# 37385  11069  09:32:10    ปกติ (เหลืองใส)   4        10986     นาย  ...
# 37400  11069  11:52:34     มีเม็ดเลือดแดง   4        11002    น.ส.  ...
#
#       amphurcode          amphur tamboncode     tambon code4  \
# 0            7.0           พิชัย        2.0   บ้านดารา  18.0
# 1           18.0         ฆ้องชัย        3.0   โคกสะอาด  18.0
# 7            1.0  เมืองอุตรดิตถ์        9.0    งิ้วงาม  18.0
# 10           1.0  เมืองอุตรดิตถ์       13.0     วังดิน  18.0
# 11           6.0           บรบือ       20.0     ดอนงัว  18.0
# ...          ...             ...        ...        ...   ...
# 37302        8.0  พยัคฆภูมิพิสัย        1.0     ปะหลาน   7.0
# 37359       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37374       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37385       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
# 37400       10.0         เสลภูมิ       17.0  ขวัญเมือง   7.0
#
#                              name5 code9                  name10 short_thai  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         กส
# 7      โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 10     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         อต
# 11     โรงพยาบาลส่งเสริมสุขภาพตำบล  10.0               1 ปฐมภูมิ         มค
# ...                            ...   ...                     ...        ...
# 37302               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         มค
# 37359               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37374               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37385               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
# 37400               โรงพยาบาลชุมชน  22.0  2.2 ทุติยภูมิระดับกลาง         รอ
#
#        short_english
# 0                UTT
# 1                KSN
# 7                UTT
# 10               UTT
# 11               MKM
# ...              ...
# 37302            MKM
# 37359            RET
# 37374            RET
# 37385            RET
# 37400            RET
#
# [2830 rows x 27 columns]

# %%
ov_4 = ov_4.groupby('province').count()
ov_4_new = ov_4.iloc[:,:1]
ov_4_noindex = ov_4_new.reset_index()
ov_4_noindex
# Out:
#     province  user
# 0  กาฬสินธุ์   645
# 1    ขอนแก่น    87
# 2  มหาสารคาม   765
# 3   ร้อยเอ็ด  1017
# 4  อุตรดิตถ์   316

# %%
o4 = {'user':'จำนวนที่พบโรค ระดับ 4'}
# call rename () method
ov_4_noindex.rename(columns=o4,
          inplace=True)
ov_4_noindex
# Out:
#     province  จำนวนที่พบโรค ระดับ 4
# 0  กาฬสินธุ์                    645
# 1    ขอนแก่น                     87
# 2  มหาสารคาม                    765
# 3   ร้อยเอ็ด                   1017
# 4  อุตรดิตถ์                    316

# %% [markdown]
# ### รวมตาราง 4 ตารางเข้าด้วยกัน

# %%
ov_merge = ov_0_noindex.merge(ov_1_noindex,how='left',left_on='province',right_on='province') 
ov_merge = ov_merge.merge(ov_2_noindex,how='left',left_on='province',right_on='province') 
ov_merge = ov_merge.merge(ov_3_noindex,how='left',left_on='province',right_on='province') 
ov_merge = ov_merge.merge(ov_4_noindex,how='left',left_on='province',right_on='province') 
ov_merge
# Out:
#        province  จำนวนที่พบโรค ระดับ 0  จำนวนที่พบโรค ระดับ 1  \
# 0     กาฬสินธุ์                   5190                  916.0
# 1       ขอนแก่น                   3315                  551.0
# 2        นครพนม                      2                    2.0
# 3    นครราชสีมา                      1                    NaN
# 4     มหาสารคาม                   3960                 2104.0
# 5      มุกดาหาร                      2                    NaN
# 6      ร้อยเอ็ด                   7029                 3051.0
# 7      ศรีสะเกษ                      1                    1.0
# 8        สกลนคร                      3                    3.0
# 9     อุตรดิตถ์                   1517                  453.0
# 10  อุบลราชธานี                      1                    NaN
#
#     จำนวนที่พบโรค ระดับ 2  จำนวนที่พบโรค ระดับ 3  จำนวนที่พบโรค ระดับ 4
# 0                   541.0                  522.0                  645.0
# 1                   164.0                  125.0                   87.0
# 2                     NaN                    1.0                    NaN
# 3                     NaN                    NaN                    NaN
# 4                  1183.0                  884.0                  765.0
# 5                     NaN                    NaN                    NaN
# 6                  1396.0                 1163.0                 1017.0
# 7                     1.0                    NaN                    NaN
# 8                     NaN                    NaN                    NaN
# 9                   234.0                  258.0                  316.0
# 10                    NaN                    NaN                    NaN

# %%
# เเทนค่า NaN ด้วย 0
ov_merge['จำนวนที่พบโรค ระดับ 1'] = ov_merge['จำนวนที่พบโรค ระดับ 1'].fillna(0) 
ov_merge['จำนวนที่พบโรค ระดับ 2'] = ov_merge['จำนวนที่พบโรค ระดับ 2'].fillna(0) 
ov_merge['จำนวนที่พบโรค ระดับ 3'] = ov_merge['จำนวนที่พบโรค ระดับ 3'].fillna(0) 
ov_merge['จำนวนที่พบโรค ระดับ 4'] = ov_merge['จำนวนที่พบโรค ระดับ 4'].fillna(0)

# %%
ov_merge.isnull().any()
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# province                 False
# จำนวนที่พบโรค ระดับ 0    False
# จำนวนที่พบโรค ระดับ 1    False
# จำนวนที่พบโรค ระดับ 2    False
# จำนวนที่พบโรค ระดับ 3    False
# จำนวนที่พบโรค ระดับ 4    False
# dtype: bool

# %% [markdown]
# # Dashboard 1
#
# รวมตารางระหว่างจำนวนการตรวจในแต่ละพื้นที่ กับ จำนวนที่พบโรค

# %%
data1 = P_noindex.merge(ov_merge,how='left',left_on='province',right_on='province') 
data1
# Out:
#        province  จำนวนการตรวจในแต่ละพื้นที่  จำนวนที่พบโรค ระดับ 0  \
# 0     กาฬสินธุ์                        7814                 5190.0
# 1       ขอนแก่น                        4242                 3315.0
# 2        นครพนม                           5                    2.0
# 3    นครราชสีมา                           1                    1.0
# 4     มหาสารคาม                        8896                 3960.0
# 5      มุกดาหาร                           2                    2.0
# 6      ร้อยเอ็ด                       13656                 7029.0
# 7         ลำปาง                           1                    NaN
# 8      ศรีสะเกษ                           3                    1.0
# 9        สกลนคร                           6                    3.0
# 10     อุดรธานี                           1                    NaN
# 11    อุตรดิตถ์                        2778                 1517.0
# 12  อุบลราชธานี                           1                    1.0
#
#     จำนวนที่พบโรค ระดับ 1  จำนวนที่พบโรค ระดับ 2  จำนวนที่พบโรค ระดับ 3  \
# 0                   916.0                  541.0                  522.0
# 1                   551.0                  164.0                  125.0
# 2                     2.0                    0.0                    1.0
# 3                     0.0                    0.0                    0.0
# 4                  2104.0                 1183.0                  884.0
# 5                     0.0                    0.0                    0.0
# 6                  3051.0                 1396.0                 1163.0
# 7                     NaN                    NaN                    NaN
# 8                     1.0                    1.0                    0.0
# 9                     3.0                    0.0                    0.0
# 10                    NaN                    NaN                    NaN
# 11                  453.0                  234.0                  258.0
# 12                    0.0                    0.0                    0.0
#
#     จำนวนที่พบโรค ระดับ 4
# 0                   645.0
# 1                    87.0
# 2                     0.0
# 3                     0.0
# 4                   765.0
# 5                     0.0
# 6                  1017.0
# 7                     NaN
# 8                     0.0
# 9                     0.0
# 10                    NaN
# 11                  316.0
# 12                    0.0

# %%
# เเทนค่า NaN ด้วย 0
data1['จำนวนที่พบโรค ระดับ 0'] = data1['จำนวนที่พบโรค ระดับ 0'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 1'] = data1['จำนวนที่พบโรค ระดับ 1'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 2'] = data1['จำนวนที่พบโรค ระดับ 2'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 3'] = data1['จำนวนที่พบโรค ระดับ 3'].fillna(0) 
data1['จำนวนที่พบโรค ระดับ 4'] = data1['จำนวนที่พบโรค ระดับ 4'].fillna(0)

# %%
data1.isnull().any()
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
#.any() เพื่อดูรายละเอียดการเปรียบเทียบข้อมูลให้ออกมาในรูป true false
# Out:
# province                      False
# จำนวนการตรวจในแต่ละพื้นที่    False
# จำนวนที่พบโรค ระดับ 0         False
# จำนวนที่พบโรค ระดับ 1         False
# จำนวนที่พบโรค ระดับ 2         False
# จำนวนที่พบโรค ระดับ 3         False
# จำนวนที่พบโรค ระดับ 4         False
# dtype: bool

# %%
data1 # แสดงข้อมูลหลังเเทน NaN ด้วย 0
# Out:
#        province  จำนวนการตรวจในแต่ละพื้นที่  จำนวนที่พบโรค ระดับ 0  \
# 0     กาฬสินธุ์                        7814                 5190.0
# 1       ขอนแก่น                        4242                 3315.0
# 2        นครพนม                           5                    2.0
# 3    นครราชสีมา                           1                    1.0
# 4     มหาสารคาม                        8896                 3960.0
# 5      มุกดาหาร                           2                    2.0
# 6      ร้อยเอ็ด                       13656                 7029.0
# 7         ลำปาง                           1                    0.0
# 8      ศรีสะเกษ                           3                    1.0
# 9        สกลนคร                           6                    3.0
# 10     อุดรธานี                           1                    0.0
# 11    อุตรดิตถ์                        2778                 1517.0
# 12  อุบลราชธานี                           1                    1.0
#
#     จำนวนที่พบโรค ระดับ 1  จำนวนที่พบโรค ระดับ 2  จำนวนที่พบโรค ระดับ 3  \
# 0                   916.0                  541.0                  522.0
# 1                   551.0                  164.0                  125.0
# 2                     2.0                    0.0                    1.0
# 3                     0.0                    0.0                    0.0
# 4                  2104.0                 1183.0                  884.0
# 5                     0.0                    0.0                    0.0
# 6                  3051.0                 1396.0                 1163.0
# 7                     0.0                    0.0                    0.0
# 8                     1.0                    1.0                    0.0
# 9                     3.0                    0.0                    0.0
# 10                    0.0                    0.0                    0.0
# 11                  453.0                  234.0                  258.0
# 12                    0.0                    0.0                    0.0
#
#     จำนวนที่พบโรค ระดับ 4
# 0                   645.0
# 1                    87.0
# 2                     0.0
# 3                     0.0
# 4                   765.0
# 5                     0.0
# 6                  1017.0
# 7                     0.0
# 8                     0.0
# 9                     0.0
# 10                    0.0
# 11                  316.0
# 12                    0.0

# %%
data1.to_csv(os.path.join(path,'data1.csv')) # save เข้า drive เพื่อนำไปทำ dashboard

# %% [markdown]
# # Dashboard 2
#
# ข้อมูลที่เหลือ
#
# * ช่วงเวลาที่ตรวจ (date ในไฟล์ alldb.csv)
# * อื่นๆที่นักศึกษาเห็นว่าเป็นประโยชน์ (phone (ชนิดโทรศัพท์ที่ใช้บันทึก), title (คำนำหน้าชื่อ), age (อายุ))

# %%
merged_use = merged_drop[['user','date','phone','site','time','urine','ov','PartitionKey','hcode','name','province','title','age']] 
merged_use
# Out:
#         user       date       phone   site      time  \
# 0      12015 2022-03-30  iPhone12,3  06307  14:46:08
# 1      91811 2022-03-30  iPhone14,3  05328  15:27:45
# 2      95821 2022-03-30  iPhone13,4  06302  10:16:46
# 3      13361 2022-03-29   iPhone9,4  05059  12:26:38
# 4      28241 2022-03-31  iPhone13,3  06334  14:57:41
# ...      ...        ...         ...    ...       ...
# 37401  26462 2022-03-22   Vivo 1920  11069  14:03:12
# 37402  26462 2022-03-21   Vivo 1920  11069  13:59:04
# 37403  26462 2022-03-22  iPhone13,4  11069  13:41:47
# 37404  26462 2022-03-21  iPhone13,4  11069  14:17:46
# 37405  26462 2022-03-21  Vivo V2050  11069  10:54:49
#
#                                   urine  ov PartitionKey  hcode  \
# 0                       ปกติ (เหลืองใส)   4        00001  06307
# 1                       ปกติ (เหลืองใส)   4        00001  05328
# 2                       ปกติ (เหลืองใส)   3        00001  06302
# 3                       ปกติ (เหลืองใส)   3        00001  05059
# 4                       ปกติ (เหลืองใส)   0        00001  06334
# ...                                 ...  ..          ...    ...
# 37401                   ปกติ (เหลืองใส)   1        11003  11069
# 37402                   ปกติ (เหลืองใส)   2        11005  11069
# 37403                   ปกติ (เหลืองใส)   2        11006  11069
# 37404                   ปกติ (เหลืองใส)   0        11007  11069
# 37405  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008  11069
#
#                                                     name   province   title  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา  อุตรดิตถ์  นางสาว
# 1            โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์  กาฬสินธุ์     นาง
# 2                     โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง  อุตรดิตถ์     นาง
# 3                  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่  มหาสารคาม     นาย
# 4                      โรงพยาบาลส่งเสริมสุขภาพตำบลน้ำพี้  อุตรดิตถ์  นางสาว
# ...                                                  ...        ...     ...
# 37401                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด  นางสาว
# 37402                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาย
# 37403                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาง
# 37404                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาง
# 37405                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาย
#
#       age
# 0      47
# 1      41
# 2      55
# 3      66
# 4      50
# ...    ..
# 37401  33
# 37402  28
# 37403  72
# 37404  48
# 37405  36
#
# [37406 rows x 13 columns]

# %%
merged_use1 = pd.DataFrame(merged_use)
merged_use1['Day'] = pd.to_datetime(merged_use['date'], format = "%Y/%m/%d")
merged_use1['Month'] = merged_use['date'].dt.month
merged_use1['Year'] = merged_use['date'].dt.year
merged_use1
# Out:
#         user       date       phone   site      time  \
# 0      12015 2022-03-30  iPhone12,3  06307  14:46:08
# 1      91811 2022-03-30  iPhone14,3  05328  15:27:45
# 2      95821 2022-03-30  iPhone13,4  06302  10:16:46
# 3      13361 2022-03-29   iPhone9,4  05059  12:26:38
# 4      28241 2022-03-31  iPhone13,3  06334  14:57:41
# ...      ...        ...         ...    ...       ...
# 37401  26462 2022-03-22   Vivo 1920  11069  14:03:12
# 37402  26462 2022-03-21   Vivo 1920  11069  13:59:04
# 37403  26462 2022-03-22  iPhone13,4  11069  13:41:47
# 37404  26462 2022-03-21  iPhone13,4  11069  14:17:46
# 37405  26462 2022-03-21  Vivo V2050  11069  10:54:49
#
#                                   urine  ov PartitionKey  hcode  \
# 0                       ปกติ (เหลืองใส)   4        00001  06307
# 1                       ปกติ (เหลืองใส)   4        00001  05328
# 2                       ปกติ (เหลืองใส)   3        00001  06302
# 3                       ปกติ (เหลืองใส)   3        00001  05059
# 4                       ปกติ (เหลืองใส)   0        00001  06334
# ...                                 ...  ..          ...    ...
# 37401                   ปกติ (เหลืองใส)   1        11003  11069
# 37402                   ปกติ (เหลืองใส)   2        11005  11069
# 37403                   ปกติ (เหลืองใส)   2        11006  11069
# 37404                   ปกติ (เหลืองใส)   0        11007  11069
# 37405  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008  11069
#
#                                                     name   province   title  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา  อุตรดิตถ์  นางสาว
# 1            โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์  กาฬสินธุ์     นาง
# 2                     โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง  อุตรดิตถ์     นาง
# 3                  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่  มหาสารคาม     นาย
# 4                      โรงพยาบาลส่งเสริมสุขภาพตำบลน้ำพี้  อุตรดิตถ์  นางสาว
# ...                                                  ...        ...     ...
# 37401                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด  นางสาว
# 37402                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาย
# 37403                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาง
# 37404                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาง
# 37405                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด     นาย
#
#       age        Day  Month  Year
# 0      47 2022-03-30      3  2022
# 1      41 2022-03-30      3  2022
# 2      55 2022-03-30      3  2022
# 3      66 2022-03-29      3  2022
# 4      50 2022-03-31      3  2022
# ...    ..        ...    ...   ...
# 37401  33 2022-03-22      3  2022
# 37402  28 2022-03-21      3  2022
# 37403  72 2022-03-22      3  2022
# 37404  48 2022-03-21      3  2022
# 37405  36 2022-03-21      3  2022
#
# [37406 rows x 16 columns]

# %%
merged_use['Month'].unique()
# Out:
# array([3, 4, 2])

# %%
merged_use['title'].unique()
# Out:
# array(['นางสาว', 'นาง', 'นาย', 'น.ส.', 'นส.', 'น.ส', 'นาย ', 'นส', 'ด.ญ.',
#        'นาง ', 'ร.ต.ต.', ' นาง', '  นาง', 'ว่าที่ ร.ต.', 'นางl',
#        'ว่าที่ร้อยตรี', 'นส. ', 'พจอ.', 'น.ส ', 'พระ', 'Mrs', 'นา่ง',
#        'นาย  ', 'น', 'ร.ต.', 'พระครุ', 'นาบ', 'นางสาว ', 'ชาย', 'ด.ต.',
#        'data is not completed', 'น่าย', 'เด็กชาย',
#        'นางสาว                   ', 'ว่าที่ ร.ท.', 'นาน', 'นาว',
#        ' นางสาว', 'ร.ต.ท.', 'นาง.', 'ด.ช.', 'เด็กหญิง', 'ืนาง', 'นาวสาว',
#        ' นาย', 'ส.อ.', 'พระปลัด', 'พลฯ', 'ร.ต.อ.'], dtype=object)

# %%
merged_use1['title'].replace({'นางสาว':'หญิง','นาง':'หญิง','นาย':'ชาย','น.ส.':'หญิง','นาย ':'ชาย','นส':'หญิง','ด.ญ.':'หญิง',
                                           'นาง ':'หญิง','ร.ต.ต.':'ไม่ปรากฏข้อมูล',' นาง':'หญิง',
                              '  นาง':'หญิง','ว่าที่ ร.ต.':'ไม่ปรากฏข้อมูล','นางl':'หญิง','ว่าที่ร้อยตรี':'ไม่ปรากฏข้อมูล',
                              'นส. ':'หญิง','พจอ.':'ไม่ปรากฏข้อมูล',
                              'น.ส ':'หญิง','พระ':'ชาย','Mrs':'หญิง','นา่ง':'หญิง',
                                           'นาย  ':'ชาย','น':'ไม่ปรากฏข้อมูล','ร.ต.':'ไม่ปรากฏข้อมูล','พระครุ':'ชาย','นาบ':'ชาย','นางสาว ':'หญิง','ชาย':'ชาย','ด.ต.':'ไม่ปรากฏข้อมูล',
                              'data is not completed':'ไม่ปรากฏข้อมูล','น่าย':'ชาย','เด็กชาย':'ชาย','นางสาว                   ':'หญิง','ว่าที่ ร.ท.':'ไม่ปรากฏข้อมูล','นาน':'ชาย','นาว':'หญิง',
                             ' นางสาว':'หญิง','ร.ต.ท.':'ไม่ปรากฏข้อมูล','นาง.':'หญิง','ด.ช.':'ชาย','เด็กหญิง':'หญิง', 'ืนาง':'หญิง','นาวสาว':'หญิง',
                               ' นาย':'ชาย','ส.อ.':'ไม่ปรากฏข้อมูล','พระปลัด':'ชาย','พลฯ':'ชาย','ร.ต.อ.':'ไม่ปรากฏข้อมูล','นส.':'หญิง','น.ส':'หญิง'}, inplace=True ) 
merged_use1['title'].unique()
# Out:
# array(['หญิง', 'ชาย', 'ไม่ปรากฏข้อมูล'], dtype=object)

# %%
merged_use1
# Out:
#         user       date       phone   site      time  \
# 0      12015 2022-03-30  iPhone12,3  06307  14:46:08
# 1      91811 2022-03-30  iPhone14,3  05328  15:27:45
# 2      95821 2022-03-30  iPhone13,4  06302  10:16:46
# 3      13361 2022-03-29   iPhone9,4  05059  12:26:38
# 4      28241 2022-03-31  iPhone13,3  06334  14:57:41
# ...      ...        ...         ...    ...       ...
# 37401  26462 2022-03-22   Vivo 1920  11069  14:03:12
# 37402  26462 2022-03-21   Vivo 1920  11069  13:59:04
# 37403  26462 2022-03-22  iPhone13,4  11069  13:41:47
# 37404  26462 2022-03-21  iPhone13,4  11069  14:17:46
# 37405  26462 2022-03-21  Vivo V2050  11069  10:54:49
#
#                                   urine  ov PartitionKey  hcode  \
# 0                       ปกติ (เหลืองใส)   4        00001  06307
# 1                       ปกติ (เหลืองใส)   4        00001  05328
# 2                       ปกติ (เหลืองใส)   3        00001  06302
# 3                       ปกติ (เหลืองใส)   3        00001  05059
# 4                       ปกติ (เหลืองใส)   0        00001  06334
# ...                                 ...  ..          ...    ...
# 37401                   ปกติ (เหลืองใส)   1        11003  11069
# 37402                   ปกติ (เหลืองใส)   2        11005  11069
# 37403                   ปกติ (เหลืองใส)   2        11006  11069
# 37404                   ปกติ (เหลืองใส)   0        11007  11069
# 37405  ปกติ (เหลืองใส), ใส่เป็นน้ำเปล่า   1        11008  11069
#
#                                                     name   province title age  \
# 0      โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา  อุตรดิตถ์  หญิง  47
# 1            โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์  กาฬสินธุ์  หญิง  41
# 2                     โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง  อุตรดิตถ์  หญิง  55
# 3                  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่  มหาสารคาม   ชาย  66
# 4                      โรงพยาบาลส่งเสริมสุขภาพตำบลน้ำพี้  อุตรดิตถ์  หญิง  50
# ...                                                  ...        ...   ...  ..
# 37401                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด  หญิง  33
# 37402                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด   ชาย  28
# 37403                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด  หญิง  72
# 37404                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด  หญิง  48
# 37405                                   โรงพยาบาลเสลภูมิ   ร้อยเอ็ด   ชาย  36
#
#              Day  Month  Year
# 0     2022-03-30      3  2022
# 1     2022-03-30      3  2022
# 2     2022-03-30      3  2022
# 3     2022-03-29      3  2022
# 4     2022-03-31      3  2022
# ...          ...    ...   ...
# 37401 2022-03-22      3  2022
# 37402 2022-03-21      3  2022
# 37403 2022-03-22      3  2022
# 37404 2022-03-21      3  2022
# 37405 2022-03-21      3  2022
#
# [37406 rows x 16 columns]

# %%
merged_use1.to_csv(os.path.join(path,'merged_use.csv')) # save เข้า drive เพื่อนำไปทำ dashboard

# %% [markdown]
# ลิงค์ Dashboard
#
# Link: https://datastudio.google.com/reporting/a76882b0-d2de-409a-a7b9-b9d4b4a6061a
